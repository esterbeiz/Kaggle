# %%
"""
Uses the historical list of Kaggle competitions from here:
https://github.com/EliotAndres/kaggle-past-solutions/blob/master/competitions.yaml 

And outputs a CSV file with same information.
"""
import yaml
import pandas as pd
import json


stream = open('competitions.yaml', 'r')
cs = json.dumps(yaml.load(stream))
competitions = pd.read_json(cs, orient='records')
del competitions['userHasEntered'] # Relative to the user getting the data, irrelevant.
competitions.to_csv('competitions.csv', index=False)

# %%
"""
Takes a file with Kaggle competition data and outputs a file with the private leaderboards.
It uses competitionId and the internal API used in Kaggle web site (not scraping or the official API).
"""

import pandas as pd
import requests as rq
import time
import json

url = 'https://kaggle.com/c/{}/leaderboard.json?includeBeforeUser=true&includeAfterUser=false&type=private'
competitions = pd.read_csv('competitions.csv')

t = []
for _, row in competitions.iterrows():
    print("Getting data for competition:" + str(row['competitionId']))
    r = rq.get(url.format(row['competitionId']))
    res = r.json()
    if isinstance(res, dict) and res.get("beforeUser", False):
        t.extend(map(lambda x: x.update({'competitionId':row['competitionId']}) or x, res["beforeUser"]))
    if isinstance(res, dict) and res.get("afterUser", False):
        t.extend(map(lambda x: x.update({'competitionId':row['competitionId']}) or x, res["afterUser"]))
    time.sleep(1) # just to be polite to Kaggle.

teams = pd.read_json(json.dumps(t), orient='records')

#----
# Getting a new column to identify teams as (teamName attribute is not unique for members)
# the set of users.
#-----
def getUniqueTeamMembers(teamMembers):
    return sorted(set([t['profileUrl'] for t in teamMembers]))

teams["realTeam"] = teams['teamMembers'].map(getUniqueTeamMembers)


teams.to_csv('teams.csv', index=False)


# ---- Alternative scraping code (finally it was not necessary).
# from requests_html import HTMLSession
#session = HTMLSession()
#r = session.get(url + row['competitionUrl']+ '/leaderboard') 
#r.html.render(sleep=3) # Load as a Web browser will do
#teams = r.html.xpath("//tr[contains(@class, 'competition-leaderboard__row')]")
#for t in teams:
#    print(t.xpath("//td[contains(@class, 'competition-leaderboard__td-team')]/text()"))
#session.close()
#time.sleep(5)
# Out:
# Getting data for competition:6004
# Getting data for competition:4699
# Getting data for competition:4571
# Getting data for competition:4657
# Getting data for competition:4494
# Getting data for competition:4504
# Getting data for competition:4704
# Getting data for competition:4521
# Getting data for competition:4594
# Getting data for competition:4523
# Getting data for competition:4487
# Getting data for competition:4493
# Getting data for competition:4488
# Getting data for competition:4481
# Getting data for competition:4467
# Getting data for competition:4471
# Getting data for competition:4453
# Getting data for competition:4438
# Getting data for competition:4104
# Getting data for competition:4407
# Getting data for competition:4366
# Getting data for competition:4280
# Getting data for competition:4272
# Getting data for competition:4066
# Getting data for competition:3978
# Getting data for competition:4031
# Getting data for competition:4120
# Getting data for competition:3973
# Getting data for competition:3984
# Getting data for competition:3887
# Getting data for competition:3951
# Getting data for competition:3929
# Getting data for competition:3897
# Getting data for competition:3778
# Getting data for competition:3788
# Getting data for competition:3706
# Getting data for competition:3867
# Getting data for competition:3757
# Getting data for competition:3670
# Getting data for competition:3532
# Getting data for competition:3618
# Getting data for competition:3599
# Getting data for competition:3504
# Getting data for competition:3526
# Getting data for competition:2969
# Getting data for competition:3403
# Getting data for competition:3525
# Getting data for competition:3338
# Getting data for competition:3445
# Getting data for competition:3446
# Getting data for competition:3493
# Getting data for competition:3316
# Getting data for competition:3469
# Getting data for competition:3353
# Getting data for competition:2496
# Getting data for competition:3342
# Getting data for competition:3288
# Getting data for competition:3294
# Getting data for competition:3108
# Getting data for competition:3043
# Getting data for competition:2975
# Getting data for competition:2863
# Getting data for competition:2963
# Getting data for competition:2840
# Getting data for competition:2780
# Getting data for competition:2748
# Getting data for competition:2749
# Getting data for competition:2667
# Getting data for competition:2732
# Getting data for competition:2889
# Getting data for competition:2602
# Getting data for competition:2606
# Getting data for competition:3321
# Getting data for competition:2589
# Getting data for competition:2564
# Getting data for competition:2551
# Getting data for competition:2609
# Getting data for competition:2549
# Getting data for competition:2509
# Getting data for competition:2518
# Getting data for competition:2499
# Getting data for competition:2487
# Getting data for competition:2489
# Getting data for competition:2479
# Getting data for competition:2488
# Getting data for competition:2478
# Getting data for competition:2445
# Getting data for competition:2467
# Getting data for competition:2454
# Getting data for competition:2464
# Getting data for competition:2452
# Getting data for competition:2447
# Getting data for competition:2439
# Getting data for competition:2448
# Getting data for competition:2435
# Getting data for competition:2438
# Getting data for competition:2442
# Getting data for competition:2408
# Getting data for competition:5558
# Getting data for competition:5357
# Getting data for competition:5261
# Getting data for competition:5340
# Getting data for competition:5260
# Getting data for competition:5144
# Getting data for competition:5048
# Getting data for competition:5174
# Getting data for competition:5229
# Getting data for competition:5056
# Getting data for competition:4986
# Getting data for competition:4853
# Getting data for competition:4852
# Getting data for competition:4862
# Getting data for competition:4729
# Getting data for competition:5497
# Getting data for competition:5916
# Getting data for competition:5874
# Getting data for competition:5390
# Getting data for competition:6116
# Getting data for competition:6243
# Getting data for competition:6277
# Getting data for competition:6049
# Getting data for competition:5568
# Getting data for competition:6644
# Getting data for competition:6322
# Getting data for competition:6565
# Getting data for competition:6392
# Getting data for competition:6649
# Getting data for competition:6775
# Getting data for competition:7115
# Getting data for competition:7082
# Getting data for competition:6927
# Getting data for competition:7391
# Getting data for competition:7634
# Getting data for competition:7559
# Getting data for competition:8078
# Getting data for competition:7277
# Getting data for competition:7380
# Getting data for competition:9949
# Getting data for competition:9951
# Getting data for competition:9120
# Getting data for competition:9717
# Getting data for competition:7878
# Getting data for competition:9301
# Getting data for competition:8586
# Getting data for competition:8540
# Getting data for competition:8089
# Getting data for competition:8310
# Getting data for competition:8311
# Getting data for competition:8076

# %%
"""
"""
import pandas as pd
import numpy as np
import networkx as nx
import ast


competitions = pd.read_csv('competitions.csv', parse_dates=['deadline'])
teams = pd.read_csv('teams.csv')

G = nx.Graph()
G.add_nodes_from(competitions['competitionId'])
for key, n in G.nodes.items():
   n["type"] = "competition"
   n["name"] = competitions[competitions.competitionId == key]["competitionTitle"].values[0]
   n["url"] = competitions[competitions.competitionId == key]["competitionUrl"].values[0]


#----
# Getting a new column to identify teams as (teamName attribute is not unique for members)
# the set of users.
#-----
def getUniqueTeamMembers(teamMembers):
    """Gets a Series of strings, evaluates them as Python objects,
    gets the profile URL and then return the sorted sequence.
    """
    return sorted([t["profileUrl"] for t in ast.literal_eval(teamMembers)])

teams["realTeam"] = teams['teamMembers'].map(getUniqueTeamMembers)
print("Number of different teams:"+ str(len(teams.realTeam.transform(tuple).unique())))


G.add_nodes_from(teams.realTeam.transform(tuple).unique(), type="team")


comp_teams = np.column_stack((teams['competitionId'].values, teams['realTeam'].transform(tuple).values))
print(comp_teams)
G.add_edges_from(comp_teams)
nx.write_graphml(G, 'kaggle.xml')
# Out:
# Number of different teams:77655
# [[6004 ('/badrobot', '/grt123', '/liaofz')]
#  [6004 ('/dhammack', '/juliandewit')]
#  [6004 ('/gerbenvv', '/markjan', '/timsalimans')]
#  ...
#  [8076 ('/ayanmaity',)]
#  [8076 ('/msafi04',)]
#  [8076 ('/george96uoi',)]]

# %%
import matplotlib.pyplot as plt
nx.draw_networkx(G, with_labels=True)
plt.show()

# %%
print('Número de nodos:')
print(len(list(G.nodes())))
print('Número de aristas:')
print(len(list(G.edges())))
print('Densidad:')
print(nx.density(G))
# Out:
# Número de nodos:
# 77804
# Número de aristas:
# 148219
# Densidad:
# 4.897062040504622e-05

# %%
degree_list = []
for v in G:
    degree_list.append(G.degree(v))

print('Max degree:')
print(max(degree_list))
print('Min degree:')
print(min(degree_list))
print('Average degree:')
print(sum(degree_list)/len(degree_list))
# Out:
# Max degree:
# 7201
# Min degree:
# 0
# Average degree:
# 3.810061179373811

# %%
import networkx as nx

# %%
print(nx.is_connected(G))
# Out:
# False

# %%
print(nx.number_connected_components(G))
# Out:
# 3

# %%
print(nx.is_directed(G))
# Out:
# False

# %%
nx.clustering(G)
# Out:
# {6004: 0,
#  4699: 0,
#  4571: 0,
#  4657: 0,
#  4494: 0,
#  4504: 0,
#  4704: 0,
#  4521: 0,
#  4594: 0,
#  4523: 0,
#  4487: 0,
#  4493: 0,
#  4488: 0,
#  4481: 0,
#  4467: 0,
#  4471: 0,
#  4453: 0,
#  4438: 0,
#  4104: 0,
#  4407: 0,
#  4366: 0,
#  4280: 0,
#  4272: 0,
#  4066: 0,
#  3978: 0,
#  4031: 0,
#  4120: 0,
#  3973: 0,
#  3984: 0,
#  3887: 0,
#  3951: 0,
#  3929: 0,
#  3897: 0,
#  3778: 0,
#  3788: 0,
#  3706: 0,
#  3867: 0,
#  3757: 0,
#  3670: 0,
#  3532: 0,
#  3618: 0,
#  3599: 0,
#  3504: 0,
#  3526: 0,
#  2969: 0,
#  3403: 0,
#  3525: 0,
#  3338: 0,
#  3445: 0,
#  3446: 0,
#  3493: 0,
#  3316: 0,
#  3469: 0,
#  3353: 0,
#  2496: 0,
#  3342: 0,
#  3288: 0,
#  3294: 0,
#  3108: 0,
#  3043: 0,
#  2975: 0,
#  2863: 0,
#  2963: 0,
#  2840: 0,
#  2780: 0,
#  2748: 0,
#  2749: 0,
#  2667: 0,
#  2732: 0,
#  2889: 0,
#  2602: 0,
#  2606: 0,
#  3321: 0,
#  2589: 0,
#  2564: 0,
#  2551: 0,
#  2609: 0,
#  2549: 0,
#  2509: 0,
#  2518: 0,
#  2499: 0,
#  2487: 0,
#  2489: 0,
#  2479: 0,
#  2488: 0,
#  2478: 0,
#  2445: 0,
#  2467: 0,
#  2454: 0,
#  2464: 0,
#  2452: 0,
#  2447: 0,
#  2439: 0,
#  2448: 0,
#  2435: 0,
#  2438: 0,
#  2442: 0,
#  2408: 0,
#  5558: 0,
#  5357: 0,
#  5261: 0,
#  5340: 0,
#  5260: 0,
#  5144: 0,
#  5048: 0,
#  5174: 0,
#  5229: 0,
#  5056: 0,
#  4986: 0,
#  4853: 0,
#  4852: 0,
#  4862: 0,
#  4729: 0,
#  5497: 0,
#  5916: 0,
#  5874: 0,
#  5390: 0,
#  6116: 0,
#  6243: 0,
#  6277: 0,
#  6049: 0,
#  5568: 0,
#  6644: 0,
#  6322: 0,
#  6565: 0,
#  6392: 0,
#  6649: 0,
#  6775: 0,
#  7115: 0,
#  7082: 0,
#  6927: 0,
#  7391: 0,
#  7634: 0,
#  7559: 0,
#  8078: 0,
#  7277: 0,
#  7380: 0,
#  9949: 0,
#  9951: 0,
#  9120: 0,
#  9717: 0,
#  7878: 0,
#  9301: 0,
#  8586: 0,
#  8540: 0,
#  8089: 0,
#  8310: 0,
#  8311: 0,
#  8076: 0,
#  ('/badrobot', '/grt123', '/liaofz'): 0,
#  ('/dhammack', '/juliandewit'): 0,
#  ('/gerbenvv', '/markjan', '/timsalimans'): 0,
#  ('/jdingpku',
#   '/jiabao',
#   '/jiayuangu',
#   '/lax123',
#   '/pkuhuzq',
#   '/stevegaopku',
#   '/wanglw',
#   '/xyq676419'): 0,
#  ('/pfillard',): 0,
#  ('/georges', '/transcranial'): 0,
#  ('/falexwolf', '/julianjungwirth', '/m2dao2dar', '/niklaskoehler'): 0,
#  ('/alexryzhkov', '/andrem', '/sushize', '/titericz'): 0,
#  ('/de317070',
#   '/fgodin',
#   '/gabs48',
#   '/golondrina',
#   '/jburms',
#   '/lpigou',
#   '/resivium',
#   '/sailenav',
#   '/tnneuten',
#   '/x141d68f'): 0,
#  ('/nhlx5haze', '/simjeg'): 0,
#  ('/aguschin', '/dulyanov', '/mikhailtrofimov', '/utility'): 0,
#  ('/danielfg',): 0,
#  ('/alexch',): 0,
#  ('/fengxy', '/wanwanbeen'): 0,
#  ('/romualdj',): 0,
#  ('/aaalgo', '/gyuanfan'): 0,
#  ('/cojocchen', '/famousboy', '/junjiebai', '/kagglemonkey', '/songq03'): 0,
#  ('/jacobkie',): 0,
#  ('/anlthms', '/shaironen'): 0,
#  ('/jingchenma',): 0,
#  ('/ccc4321',): 0,
#  ('/zhipengjia',): 0,
#  ('/chirag1992m', '/jzbontar', '/kjgeras', '/peilunz', '/yichen'): 0,
#  ('/zeliek',): 0,
#  ('/mumech',): 0,
#  ('/bipling',): 0,
#  ('/alxvoropaev', '/bernadsky', '/lukaoo', '/quantum13'): 0,
#  ('/dejianli', '/tiankongdeguiji'): 0,
#  ('/kenjung',): 0,
#  ('/nitaidean', '/urimerhav'): 0,
#  ('/evikop', '/guyeng', '/hadarpo', '/hggshntr', '/tiferet'): 0,
#  ('/pittzzll', '/zhennany'): 0,
#  ('/u39kun',): 0,
#  ('/azureparrot',
#   '/carlosgr',
#   '/consumes',
#   '/felixgimeno',
#   '/jacoboaj',
#   '/jorditura',
#   '/josecordero',
#   '/martimayo',
#   '/mingot',
#   '/mteixido',
#   '/ricarddelgado'): 0,
#  ('/gtgtgt', '/kyoungjin', '/member', '/myunggilee', '/sjson718'): 0,
#  ('/ficusrong', '/purpleslz'): 0,
#  ('/hamidehhs',): 0,
#  ('/zfturbo',): 0,
#  ('/jiweiliu',): 0,
#  ('/lindaseok', '/ykwon0407'): 0,
#  ('/nuszeng',): 0,
#  ('/alsrgv',): 0,
#  ('/woshialex',): 0,
#  ('/basveeling',
#   '/binyam',
#   '/dimitriosm',
#   '/jrubin',
#   '/swishswish',
#   '/tstojan'): 0,
#  ('/mchahhou', '/nimashahbazi'): 0,
#  ('/dustodust', '/ecopoiesis'): 0,
#  ('/peterchang77', '/simi09'): 0,
#  ('/danielrk',): 0,
#  ('/deepimagine',): 0,
#  ('/aizvorski', '/hantah'): 0,
#  ('/abdulwahabkabani',): 0,
#  ('/savvok',): 0,
#  ('/tomascernik', '/tondracek', '/tpacko'): 0,
#  ('/sarkadiu',): 0,
#  ('/eyalis',): 0,
#  ('/qingnan',): 0,
#  ('/junshi',): 0,
#  ('/dstahlke', '/pratkar', '/saumyadip'): 0,
#  ('/cordsters', '/dbroadhead', '/dplavery92', '/langbw'): 0,
#  ('/guiber',): 0,
#  ('/fvelickovski', '/xrafael'): 0,
#  ('/flyerscan1',): 0,
#  ('/macmadman',): 0,
#  ('/pangyuteng',): 0,
#  ('/zetaochen',): 0,
#  ('/victorsd',): 0,
#  ('/symyksr',): 0,
#  ('/nedelko',): 0,
#  ('/carrendd',): 0,
#  ('/louisf',): 0,
#  ('/huxiaowei',): 0,
#  ('/goldendomer', '/topdps'): 0,
#  ('/ctsats', '/ouranos', '/voglinio'): 0,
#  ('/carryzhuzhu',): 0,
#  ('/bihanchristy', '/microljy'): 0,
#  ('/adityakumarsinha', '/lingcenfan', '/salkaa'): 0,
#  ('/happyjoe',): 0,
#  ('/londalemex',): 0,
#  ('/rasdmla',): 0,
#  ('/ofnovember', '/savfod'): 0,
#  ('/binarychan',): 0,
#  ('/bmcinnovo',): 0,
#  ('/ahkobayashi', '/mtfall'): 0,
#  ('/johngull', '/qubyxsw', '/ramzes2'): 0,
#  ('/jarrelscy',): 0,
#  ('/abriosi', '/del=c16e54e8d82063ca', '/sickocell'): 0,
#  ('/supersummer',): 0,
#  ('/keunho', '/mklim82'): 0,
#  ('/yijunliu',): 0,
#  ('/chucktown', '/hparks', '/mels630', '/sm1011'): 0,
#  ('/bluesky',): 0,
#  ('/yshrestha',): 0,
#  ('/rluethy',): 0,
#  ('/scottykwok',): 0,
#  ('/snezhko',): 0,
#  ('/zuchunshan',): 0,
#  ('/adrianmelic', '/ajulian', '/javiertag', '/virilo'): 0,
#  ('/parkinsonzabelin',): 0,
#  ('/qradiomics',): 0,
#  ('/heypeter',): 0,
#  ('/ashish9',
#   '/cr2015',
#   '/csgwon',
#   '/elvientowjf',
#   '/jtutmaher',
#   '/tangerine007'): 0,
#  ('/sekrier',): 0,
#  ('/miguelpm',): 0,
#  ('/pszoldan',): 0,
#  ('/clarkchong',): 0,
#  ('/zacharydestefano',): 0,
#  ('/zephyrd',): 0,
#  ('/illidan7',): 0,
#  ('/mathurinache',): 0,
#  ('/abnera',): 0,
#  ('/yourwanghao',): 0,
#  ('/ywkim22',): 0,
#  ('/opanichev',): 0,
#  ('/ceshine',): 0,
#  ('/julesvanligtenberg',): 0,
#  ('/dmatwork', '/prajak', '/saptarc', '/shakul20', '/thearchitect'): 0,
#  ('/svesal',): 0,
#  ('/askelpian', '/kbl4ew', '/srrobert50'): 0,
#  ('/watts2',): 0,
#  ('/isaacmg',): 0,
#  ('/albertyho', '/kunhsingyu', '/lckung', '/samcc0815'): 0,
#  ('/evgluk',): 0,
#  ('/klyusba',): 0,
#  ('/jpmiller',): 0,
#  ('/patripen26',): 0,
#  ('/shuangliu',): 0,
#  ('/marek3000',): 0,
#  ('/clustifier',): 0,
#  ('/captaindadja',): 0,
#  ('/ekonev', '/ilyaaln'): 0,
#  ('/legion007',): 0,
#  ('/roma141', '/senenbotello'): 0,
#  ('/aaberlin',
#   '/ahmedhosny',
#   '/bgwoodward',
#   '/chintanparmar',
#   '/haerts',
#   '/hexacore',
#   '/oozdemir'): 0,
#  ('/sanderdalm',): 0,
#  ('/josgilby',): 0,
#  ('/agavranis',): 0,
#  ('/etheleon', '/neoanarika'): 0,
#  ('/felmans', '/huntleym', '/khriswang', '/lucashu'): 0,
#  ('/kevinsoucy', '/lars5k', '/rivalmuc'): 0,
#  ('/paula27121990',): 0,
#  ('/linhaili',): 0,
#  ('/vicensgaitan',): 0,
#  ('/forensics409',): 0,
#  ('/hengjianjia',): 0,
#  ('/danelb', '/meniam', '/nadavl', '/nelzas', '/nslonim', '/veredfish'): 0,
#  ('/finalbad860822', '/kisara', '/liweifeng', '/lunaguan'): 0,
#  ('/arturscussel', '/escudero', '/pedrohaamorim', '/silviomoreto'): 0,
#  ('/awakebacker', '/chen121', '/graydlpnwedu', '/tomath1'): 0,
#  ('/marksalacinski',): 0,
#  ('/miguel777',): 0,
#  ('/joaopoliveira', '/jongomez'): 0,
#  ('/deepbraineu', '/fabriziodefausti'): 0,
#  ('/mikell',): 0,
#  ('/erwanlc',): 0,
#  ('/eduardoli',): 0,
#  ('/bodorin',): 0,
#  ('/semiquark1',): 0,
#  ('/ashayshah7',): 0,
#  ('/gefrix',): 0,
#  ('/caoxiaoqing',): 0,
#  ('/linbo2016',): 0,
#  ('/dlevashov', '/mshytikov'): 0,
#  ('/ibhandar', '/mpapadopulos'): 0,
#  ('/mindcool',): 0,
#  ('/laroumagne',): 0,
#  ('/jekyllsmith',): 0,
#  ('/katharineruoxi', '/stevenliuyi'): 0,
#  ('/bingqingzhang', '/jstzhyd', '/shsnail', '/thebear123'): 0,
#  ('/kambarakun',): 0,
#  ('/ronoliverocs',): 0,
#  ('/mfrank',): 0,
#  ('/dmayeda',): 0,
#  ('/sadz2201',): 0,
#  ('/alijs1',): 0,
#  ('/ankasor',): 0,
#  ('/cgratie', '/lvaleriu'): 0,
#  ('/janosk21',): 0,
#  ('/madhurgoel',): 0,
#  ('/garethjns',): 0,
#  ('/heathmccasland', '/jacobdeecurtis'): 0,
#  ('/harwester',): 0,
#  ('/ronpatrick',): 0,
#  ('/joe1987',): 0,
#  ('/mlu821',): 0,
#  ('/ecentury',): 0,
#  ('/alanlnguyen',
#   '/cfried123',
#   '/ericabrauer',
#   '/hatfieldm48',
#   '/hollifieldzachary',
#   '/joshbaker',
#   '/ldcolosi',
#   '/mjbrienza',
#   '/penguinskid',
#   '/soniahinson',
#   '/znuzzo'): 0,
#  ('/amalhotra', '/jsardinha'): 0,
#  ('/woomky',): 0,
#  ('/anokas',): 0,
#  ('/sidharthkumar',): 0,
#  ('/meganwang', '/mikesitu', '/nicozheng', '/w52918', '/yanyang729'): 0,
#  ('/kwarner',): 0,
#  ('/drc10723',): 0,
#  ('/gshaham',): 0,
#  ('/dxchen',): 0,
#  ('/ekkus93',): 0,
#  ('/rdebbe',): 0,
#  ('/lucamassaron',): 0,
#  ('/probe301',): 0,
#  ('/jhs1728',): 0,
#  ('/amanrana20',): 0,
#  ('/hskksk',): 0,
#  ('/akoriagin', '/dearkafka', '/kirillemilio', '/podviaznikoff'): 0,
#  ('/annuuusaxena',
#   '/garchrs',
#   '/outliar',
#   '/rangerdavis',
#   '/shivangbaijal'): 0,
#  ('/mochiliu', '/sleepywyn'): 0,
#  ('/jordimas',): 0,
#  ('/jiuxu1987', '/murocks', '/parkerzf', '/xywangcs'): 0,
#  ('/jaleto',): 0,
#  ('/craigglastonbury', '/kirk86', '/wrosinski'): 0,
#  ('/lyapinnr',): 0,
#  ('/praveenadepu',): 0,
#  ('/clavichord93',): 0,
#  ('/oraculseed',): 0,
#  ('/jaybob20',): 0,
#  ('/mcasshy',): 0,
#  ('/del=2fcc0575facc0452', '/michaelxiao', '/posiedon', '/tonygao'): 0,
#  ('/aastalin', '/tungty'): 0,
#  ('/jbrasher6', '/rrp9999'): 0,
#  ('/dhegde',): 0,
#  ('/hidy0503', '/mdsfdwei1'): 0,
#  ('/edelbert', '/gabidentanekeev'): 0,
#  ('/mstrhw',): 0,
#  ('/cyllyue', '/iridescent', '/jiangqy', '/jingyou2017'): 0,
#  ('/lolitacoder',): 0,
#  ('/jakublangr', '/pavan4'): 0,
#  ('/niallm',): 0,
#  ('/hewang',
#   '/kentsyx',
#   '/lihuiminphd',
#   '/namasamita',
#   '/ozzzzzp',
#   '/qiangfd',
#   '/ronniezhou'): 0,
#  ('/cpmpml', '/datasciencekrk', '/elliotw', '/lukaszcmielowski'): 0,
#  ('/lucy00', '/nanisbad'): 0,
#  ('/zhangxiaoya1993',): 0,
#  ('/rdcolema',): 0,
#  ('/maciejv',): 0,
#  ('/andrewszot',
#   '/arthurshau',
#   '/harshipr',
#   '/rachitkataria',
#   '/yunalee22'): 0,
#  ('/astaria', '/chpark', '/dyaprk', '/keeyoung', '/kwanghee', '/pubmed'): 0,
#  ('/lamthuy',): 0,
#  ('/medial',): 0,
#  ('/dev7il',
#   '/gberinger',
#   '/jpowierza',
#   '/kryhebel',
#   '/maciejbudys',
#   '/matjabl',
#   '/nordberdt',
#   '/paluchowskid'): 0,
#  ('/shaziatoronto', '/sylvesterchiang'): 0,
#  ('/jeffhebert',): 0,
#  ('/ic3fr0g', '/manrajsingh', '/rmanuuu', '/shamssam'): 0,
#  ('/lizhen3201',): 0,
#  ('/eduzznet',): 0,
#  ('/ggggfan',): 0,
#  ('/clover9gu',): 0,
#  ('/applejus',): 0,
#  ('/del=bb3a2820312ac701',): 0,
#  ('/danieleewww',): 0,
#  ('/andyqiu', '/anuar12', '/chengxie', '/schorlem'): 0,
#  ('/ampires', '/jbranco'): 0,
#  ('/ernestyalumni',): 0,
#  ('/maplelin', '/ycsos0'): 0,
#  ('/phawishi',): 0,
#  ('/sambitnandi',): 0,
#  ('/ryutek',): 0,
#  ('/chalfacre',): 0,
#  ('/kaggle4mayank',): 0,
#  ('/ivanl1',): 0,
#  ('/anilhk', '/muralimnk'): 0,
#  ('/alesgb', '/andreikaralkou', '/orkenstein'): 0,
#  ('/wakeup06',): 0,
#  ('/rocelot',): 0,
#  ('/ttucphares', '/tturubie'): 0,
#  ('/enriquebalp',): 0,
#  ('/bioruben', '/masreal'): 0,
#  ('/bhillmann',): 0,
#  ('/esuerid', '/junharin', '/kihwan'): 0,
#  ('/yunkyong',): 0,
#  ('/fskidmore', '/godaibo', '/thomasal'): 0,
#  ('/psaadbye',): 0,
#  ('/filareta',): 0,
#  ('/aijiang', '/lszhang'): 0,
#  ('/del=121b7398bccb8e5a',): 0,
#  ('/asonora', '/bjansen', '/epapavas', '/lomelina', '/panosgon'): 0,
#  ('/terravic',): 0,
#  ('/whukui',): 0,
#  ('/thekokonuts',): 0,
#  ('/willieliao',): 0,
#  ('/dimasakovich', '/josemarcosrf', '/kostidov', '/shevva'): 0,
#  ('/gaurav705362', '/ttus09'): 0,
#  ('/igorkrashenyi',): 0,
#  ('/north1605', '/wezemer'): 0,
#  ('/parthassatpathy', '/rashmitarouy01'): 0,
#  ('/potatoface',): 0,
#  ('/samxie',): 0,
#  ('/tunguz',): 0,
#  ('/rodenluo',): 0,
#  ('/atuljjoshi05',): 0,
#  ('/paulorzp',): 0,
#  ('/indianotaku', '/saigouthamttu'): 0,
#  ('/vbardiovsky',): 0,
#  ('/chipmonkey',): 0,
#  ('/olivierc',): 0,
#  ('/agrawroh', '/jeremyxtq', '/thepratik', '/wenjun93'): 0,
#  ('/nhargan',): 0,
#  ('/shleedynamics',): 0,
#  ('/boleszek',): 0,
#  ('/wzwrwjbsy',): 0,
#  ('/nvpiao',): 0,
#  ('/georgiaphi1389', '/msugimura', '/rhaughey'): 0,
#  ('/wcukierski',): 0,
#  ('/ascreven',
#   '/daewoo',
#   '/fanc5804',
#   '/jackbarry',
#   '/karibdo',
#   '/lusevier',
#   '/maddiemesard',
#   '/realviacauchy'): 0,
#  ('/alexeylive',): 0,
#  ('/carloshuertas',): 0,
#  ('/jzima7',): 0,
#  ('/luoyuxuanlyx',): 0,
#  ('/nenezhu', '/yuanrong'): 0,
#  ('/slonoslon',): 0,
#  ('/niranjanmudhiraj',): 0,
#  ('/szalmaf', '/ungsur'): 0,
#  ('/pradnyachahande', '/ttumax'): 0,
#  ('/muhammedazamkhan',): 0,
#  ('/cotouk',): 0,
#  ('/vetribox',): 0,
#  ('/cominger', '/davinnovation'): 0,
#  ('/pedram',): 0,
#  ('/kevin0319',): 0,
#  ('/barrettxav',): 0,
#  ('/spacepizza',): 0,
#  ('/vihangpatil',): 0,
#  ('/yatsura',): 0,
#  ('/engenious',): 0,
#  ('/abhikapoor', '/akashshrivastava0406', '/sahilsharma'): 0,
#  ('/fahd09',): 0,
#  ('/abhisek2204', '/birupakhya', '/mayukhss', '/saroj4kaggle'): 0,
#  ('/lawrencechernin',): 0,
#  ('/baoxiangyang', '/haoyuz', '/huili93', '/osake218'): 0,
#  ('/zongweimayo',): 0,
#  ('/abqazi', '/sdbttu'): 0,
#  ('/seemakanuri', '/ttusuresh'): 0,
#  ('/dwjwlxs',): 0,
#  ('/coroscop',): 0,
#  ('/isyebojiang',
#   '/jcausey',
#   '/jyzang',
#   '/nodulesuperx',
#   '/qualls',
#   '/shiqian',
#   '/shuzhong'): 0,
#  ('/krishnateja614',): 0,
#  ('/timon88',): 0,
#  ('/akuman', '/panditshreya', '/xidexia', '/xinye1115'): 0,
#  ('/rehband',): 0,
#  ('/alextlin',): 0,
#  ('/tangshouquan',): 0,
#  ('/grittyy',): 0,
#  ('/heryson', '/oliphilip', '/vdouetvannucci'): 0,
#  ('/ernie55ernie',): 0,
#  ('/acmh360',
#   '/andreabduque',
#   '/arturfranco',
#   '/bezerra',
#   '/brielmachado',
#   '/caminha',
#   '/castilho',
#   '/cstiano',
#   '/djeefther',
#   '/jbsn90',
#   '/larissalages',
#   '/lucasveloso',
#   '/marilugomes',
#   '/nataliakitaoka',
#   '/nilsonlima',
#   '/renatosousa',
#   '/thiagovicente',
#   '/viniciussanguinete',
#   '/wellpin'): 0,
#  ('/rats001',): 0,
#  ('/vlarine',): 0,
#  ('/feiyun',
#   '/kumargayu',
#   '/minhazul',
#   '/shengwa',
#   '/utayao',
#   '/xinliangzhu'): 0,
#  ('/elsa123',): 0,
#  ('/ferpalaciosugr',): 0,
#  ('/rjbashar',): 0,
#  ('/xyzeng',): 0,
#  ('/joshuaw', '/timbacy'): 0,
#  ('/rodrigomalacarne', '/rspadim'): 0,
#  ('/natbel4ml',): 0,
#  ('/dengyang123',
#   '/fanhongwei',
#   '/lmqmax',
#   '/sdylovesky',
#   '/sunxinlong',
#   '/sunyao123',
#   '/yiyongjian',
#   '/yuanfirstofall',
#   '/yuankehong',
#   '/zhangshengze',
#   '/zhangxueling'): 0,
#  ('/wuruiaoxue',): 0,
#  ('/laurilistak',): 0,
#  ('/jorgepalma',): 0,
#  ('/thuyenvn',): 0,
#  ('/elsazhu',): 0,
#  ('/andrekos', '/del=144d9653841ef5a9'): 0,
#  ('/zhouzhiguang',): 0,
#  ('/alberto2017',
#   '/mahmoudabdalah',
#   '/mavismu',
#   '/nandresparra',
#   '/yoganandb'): 0,
#  ('/viglia90',): 0,
#  ('/eige1123', '/lichtenberger', '/madtrini', '/xxamot'): 0,
#  ('/icostan',): 0,
#  ('/williamhau',): 0,
#  ('/ahmedanis03', '/drwaleedayousef'): 0,
#  ('/manigandanv',): 0,
#  ('/twiggy',): 0,
#  ('/kghanareddy',): 0,
#  ('/goldgof', '/lohall', '/rahulpaul', '/saeed3', '/shhawkins'): 0,
#  ('/michalstepniewski',): 0,
#  ('/quoctinphan',): 0,
#  ('/jjyang',): 0,
#  ('/seamri',): 0,
#  ('/voxelcloud',): 0,
#  ('/icanfly',): 0,
#  ('/feixyz',): 0,
#  ('/pandeyanil',): 0,
#  ('/anilcem',
#   '/cberkay',
#   '/jerryqhyu',
#   '/piercingdan',
#   '/wezteoh',
#   '/xuchanbao'): 0,
#  ('/akh64bit',): 0,
#  ('/hwasiti',): 0,
#  ('/maciek1902',): 0,
#  ('/jorgies', '/ttuawohl', '/tturay'): 0,
#  ('/rrr2016',): 0,
#  ('/zvision',): 0,
#  ('/raghuu045',): 0,
#  ('/inkfly', '/pziegenhein'): 0,
#  ('/starethics',): 0,
#  ('/pengzhao99',): 0,
#  ('/shiny2448',): 0,
#  ('/lukaszn',): 0,
#  ('/elisayao', '/qshan2170'): 0,
#  ('/okazusexy',): 0,
#  ('/wang4959520',): 0,
#  ('/bigheadwen001', '/cenlon', '/vikingy'): 0,
#  ('/simongabor',): 0,
#  ('/bohdan',): 0,
#  ('/speculation',): 0,
#  ('/qwang88',): 0,
#  ('/derkanat',): 0,
#  ('/paragkale',): 0,
#  ('/utility',): 0,
#  ('/kulishyurii',): 0,
#  ('/chechir',): 0,
#  ('/pengyan',): 0,
#  ('/fugusuki',): 0,
#  ('/famousboy',): 0,
#  ('/nekrasov',): 0,
#  ('/weimin',): 0,
#  ('/kazanova',): 0,
#  ('/anmiko',): 0,
#  ('/chenglongchen',): 0,
#  ('/samehif',): 0,
#  ('/dmitriyguller',): 0,
#  ('/zhewang',): 0,
#  ('/bishwarup',): 0,
#  ('/thawatt',): 0,
#  ('/ivanliu1989',): 0,
#  ('/danijelk',): 0,
#  ('/johnsgr17',): 0,
#  ('/vladteodorescu',): 0,
#  ('/shimva',): 0,
#  ('/raddar',): 0,
#  ('/threecourse',): 0,
#  ('/mandelbrot',): 0,
#  ('/ouranos',): 0,
#  ('/carlosfernandez',): 0,
#  ('/nthanhtam',): 0,
#  ('/breakfastpirate',): 0,
#  ('/girmak',): 0,
#  ('/chanfuku18',): 0,
#  ('/tyi2000',): 0,
#  ('/gdanschin',): 0,
#  ('/chabir',): 0,
#  ('/stocks',): 0,
#  ('/wilanw',): 0,
#  ('/trenqualye',): 0,
#  ('/davutpolat',): 0,
#  ('/inversion',): 0,
#  ('/riblidezso',): 0,
#  ('/kelexu',): 0,
#  ('/ffyu1204',): 0,
#  ('/casalicchio',): 0,
#  ('/saintex',): 0,
#  ('/zfuller',): 0,
#  ('/mt77pp',): 0,
#  ('/deanmckee',): 0,
#  ('/allexius',): 0,
#  ('/leadbest',): 0,
#  ('/paulofelipe',): 0,
#  ('/tobiri27',): 0,
#  ('/ivanhoe',): 0,
#  ('/ashhafez',): 0,
#  ('/zeroblue',): 0,
#  ('/fakeplastictrees',): 0,
#  ('/nimashahbazi',): 0,
#  ('/jhuling',): 0,
#  ('/snowdog',): 0,
#  ('/jpison',): 0,
#  ('/del=ff3f4a2063c8fa0d',): 0,
#  ('/skylibrary',): 0,
#  ('/aldente',): 0,
#  ('/tonyhong272',): 0,
#  ('/xchen0012',): 0,
#  ('/whamfish',): 0,
#  ('/sasrdw',): 0,
#  ('/qqgeogor',): 0,
#  ('/jieliu',): 0,
#  ('/ksm1978',): 0,
#  ('/nsecord',): 0,
#  ('/santiagomota',): 0,
#  ('/newtohere',): 0,
#  ('/del=baec042bc066df48',): 0,
#  ('/arturabragin',): 0,
#  ('/fohjoh',): 0,
#  ('/thequants',): 0,
#  ('/michaelxiao',): 0,
#  ('/johncandido',): 0,
#  ('/sonador',): 0,
#  ('/scirpus',): 0,
#  ('/tilgasergey',): 0,
#  ('/honeye',): 0,
#  ('/paddykb',): 0,
#  ('/kramer',): 0,
#  ('/assa2as',): 0,
#  ('/jindal',): 0,
#  ('/masandy',): 0,
#  ('/aabceh',): 0,
#  ('/prashanth058',): 0,
#  ('/cartographic',): 0,
#  ('/nutastray',): 0,
#  ('/yotamsa',): 0,
#  ('/tinken',): 0,
#  ('/thedarkl0rd',): 0,
#  ('/barisumog',): 0,
#  ('/olegkulikov',): 0,
#  ('/pseudo',): 0,
#  ('/thibmain',): 0,
#  ('/optimism',): 0,
#  ('/jturkewitz',): 0,
#  ('/lucenator',): 0,
#  ('/nianxue',): 0,
#  ('/kanosuke',): 0,
#  ('/sebda1',): 0,
#  ('/sayantan',): 0,
#  ('/sudalairajkumar',): 0,
#  ('/sushize',): 0,
#  ('/chuan92',): 0,
#  ('/ccccat',): 0,
#  ('/adityashrm21',): 0,
#  ('/dmitrylarko',): 0,
#  ('/matlab',): 0,
#  ('/mopkobb1',): 0,
#  ('/qq710467272',): 0,
#  ('/behrang',): 0,
#  ('/eransim',): 0,
#  ('/antklen',): 0,
#  ('/allmendinger',): 0,
#  ('/kg2irq13',): 0,
#  ('/iris2007',): 0,
#  ('/valadi',): 0,
#  ('/nalinpasricha',): 0,
#  ('/jayjay75',): 0,
#  ('/lishubin',): 0,
#  ('/jonathanslomka',): 0,
#  ('/pennacchio',): 0,
#  ('/dmytrolystopad',): 0,
#  ('/fe2ol3t9n301be',): 0,
#  ('/chengjiun',): 0,
#  ('/aurelg1106',): 0,
#  ('/ahereza',): 0,
#  ('/felixds',): 0,
#  ('/shahrdar',): 0,
#  ('/tmwright',): 0,
#  ('/jmannix',): 0,
#  ('/a11rand0m',): 0,
#  ('/jtrotman',): 0,
#  ('/vipito',): 0,
#  ('/summerpanda',): 0,
#  ('/kushwaha',): 0,
#  ('/vladimirmerkulov',): 0,
#  ('/ahmetekin',): 0,
#  ('/linchn',): 0,
#  ('/dithyrambe',): 0,
#  ('/mrbeer',): 0,
#  ('/ahmademad',): 0,
#  ('/timesler',): 0,
#  ('/akukamil',): 0,
#  ('/aikinogard',): 0,
#  ('/welcomeworld',): 0,
#  ('/cckk3333',): 0,
#  ('/gudunku',): 0,
#  ('/omoekan09',): 0,
#  ('/khattab34',): 0,
#  ('/yizhang4',): 0,
#  ('/andtem2000',): 0,
#  ('/xiaoqian0917',): 0,
#  ('/dweaii',): 0,
#  ('/adhirb',): 0,
#  ('/del=f16709620a6ed7e1',): 0,
#  ('/semwaldeepali',): 0,
#  ('/ag3rxx',): 0,
#  ('/jbm1966',): 0,
#  ('/skthedataguy',): 0,
#  ('/andrekos',): 0,
#  ('/nnsmedia',): 0,
#  ('/andrejonasson',): 0,
#  ('/bsgdalh',): 0,
#  ('/neshuagrawal',): 0,
#  ('/razgon',): 0,
#  ('/andreasmerentitis',): 0,
#  ('/noahxiao',): 0,
#  ('/makravch',): 0,
#  ('/kperif',): 0,
#  ('/kalleon',): 0,
#  ('/mathcap',): 0,
#  ('/sergeyivanov',): 0,
#  ('/ferris',): 0,
#  ('/mlandry',): 0,
#  ('/herozs',): 0,
#  ('/thakurrajanand',): 0,
#  ('/effywang',): 0,
#  ('/hongjiao',): 0,
#  ('/luciferase',): 0,
#  ('/jamesdlawrence',): 0,
#  ('/psilogram',): 0,
#  ('/yilihome',): 0,
#  ('/ghostmanandwoman',): 0,
#  ('/gpistre',): 0,
#  ('/androidhk',): 0,
#  ('/albertore',): 0,
#  ('/dllllb',): 0,
#  ('/oivanov',): 0,
#  ('/justfor',): 0,
#  ('/longnguyen',): 0,
#  ('/sterby',): 0,
#  ('/andreusancho',): 0,
#  ('/mordoobadi',): 0,
#  ('/tushartilwankar',): 0,
#  ('/anttip',): 0,
#  ('/xian9551',): 0,
#  ('/salacika',): 0,
#  ('/flintaxe',): 0,
#  ('/hingneabhishek',): 0,
#  ('/kyazuki',): 0,
#  ('/tr09d0r',): 0,
#  ('/thekvs',): 0,
#  ('/dreeux',): 0,
#  ('/mvansegb',): 0,
#  ('/zichen',): 0,
#  ('/rengaar',): 0,
#  ('/milivojevic',): 0,
#  ('/kyunghk',): 0,
#  ('/pierrenowak',): 0,
#  ('/mdomar',): 0,
#  ('/etelliez',): 0,
#  ('/reinhold',): 0,
#  ('/vykhand',): 0,
#  ('/del=1327ef512b2417fe',): 0,
#  ('/rpyzurich',): 0,
#  ('/nigelcarpenter',): 0,
#  ('/kevinwu06',): 0,
#  ('/mathusuthan',): 0,
#  ('/abagherp',): 0,
#  ('/vikrant24',): 0,
#  ('/melvindunn',): 0,
#  ('/thodime',): 0,
#  ('/artimous',): 0,
#  ('/dakindia',): 0,
#  ('/danielc777888',): 0,
#  ('/soumendra',): 0,
#  ('/chiggypk',): 0,
#  ('/ampaho',): 0,
#  ('/lplewa',): 0,
#  ('/tejaswagh',): 0,
#  ('/paolovigori',): 0,
#  ('/viktxn',): 0,
#  ('/lnicalo',): 0,
#  ('/bonferroni27',): 0,
#  ('/bakiev',): 0,
#  ('/titericz',): 0,
#  ('/ginoainsley',): 0,
#  ('/j55511',): 0,
#  ('/pavel1',): 0,
#  ('/robertkag',): 0,
#  ('/menaka',): 0,
#  ('/andrew31',): 0,
#  ('/happycube',): 0,
#  ('/sergii',): 0,
#  ('/del=bf30af498c9dbd5b',): 0,
#  ('/mattsharpe',): 0,
#  ('/songge',): 0,
#  ('/vinodmk',): 0,
#  ('/jianhao',): 0,
#  ('/tszkinho',): 0,
#  ('/dingran',): 0,
#  ('/seiteta',): 0,
#  ('/joswin',): 0,
#  ('/rrgiles',): 0,
#  ('/rhinodaveb',): 0,
#  ('/del=4295f5e274489eec',): 0,
#  ('/abhilashawasthi',): 0,
#  ('/odtest',): 0,
#  ('/lantingguo',): 0,
#  ('/interesting',): 0,
#  ('/dkyang',): 0,
#  ('/beteemde',): 0,
#  ('/sionek',): 0,
#  ('/bam660',): 0,
#  ('/spimenov',): 0,
#  ('/sdegirmenci',): 0,
#  ('/utah777',): 0,
#  ('/weberwu',): 0,
#  ('/klimovs',): 0,
#  ('/innerproduct',): 0,
#  ('/wootwoot',): 0,
#  ('/thedoctor46',): 0,
#  ('/bernhard1',): 0,
#  ('/patstout',): 0,
#  ('/roshankr',): 0,
#  ('/francoisneethling',): 0,
#  ('/piotrsoltysiak',): 0,
#  ('/suresubs',): 0,
#  ('/shiaukuan',): 0,
#  ('/chistyakov',): 0,
#  ('/howlingguineapig',): 0,
#  ('/iridescent',): 0,
#  ('/yihming',): 0,
#  ('/mryusa',): 0,
#  ('/maddarwin',): 0,
#  ('/kmenou',): 0,
#  ('/happyphonon',): 0,
#  ('/kaggleford',): 0,
#  ('/bpavlyshenko',): 0,
#  ('/apshreyans',): 0,
#  ('/saurabhjaju',): 0,
#  ('/t2mretro',): 0,
#  ('/yueben',): 0,
#  ('/geneva',): 0,
#  ('/georgem',): 0,
#  ('/tedferreira',): 0,
#  ('/vaseninamasha',): 0,
#  ('/sadashiv19',): 0,
#  ('/yashrajlamsal',): 0,
#  ('/skcary',): 0,
#  ('/ys19931006',): 0,
#  ('/anupam1924',): 0,
#  ('/chandlerzuo',): 0,
#  ('/mrthedave',): 0,
#  ('/andrewmatte',): 0,
#  ('/xingxu1978',): 0,
#  ('/infinitehorizon',): 0,
#  ('/frull70',): 0,
#  ('/bobcz3',): 0,
#  ('/thenx00',): 0,
#  ('/light94',): 0,
#  ('/pkovacs',): 0,
#  ('/kaushlendrasingh',): 0,
#  ('/santyago',): 0,
#  ('/sunjulee',): 0,
#  ('/rajdeltarobo',): 0,
#  ('/gingayoshizawa',): 0,
#  ('/andirey',): 0,
#  ('/cshaley',): 0,
#  ('/catzzz',): 0,
#  ('/reneboy',): 0,
#  ('/korowiow',): 0,
#  ('/cslzhl',): 0,
#  ('/mooniechen',): 0,
#  ('/qichaotang97',): 0,
#  ('/mjstoik',): 0,
#  ('/dankolbman',): 0,
#  ('/cacal39',): 0,
#  ('/vadims',): 0,
#  ('/ngcferreira',): 0,
#  ('/panosc',): 0,
#  ('/alextselikov',): 0,
#  ('/rykolt',): 0,
#  ('/robertmartin71',): 0,
#  ('/tetamhz',): 0,
#  ('/luckymomo',): 0,
#  ('/zzxzxzzxz',): 0,
#  ('/del=8cfe8dec8ae8d274',): 0,
#  ('/svpons',): 0,
#  ('/juan001',): 0,
#  ('/ramarsjillella',): 0,
#  ('/evanvanness',): 0,
#  ('/invinciblejha',): 0,
#  ('/ending',): 0,
#  ('/justinsu',): 0,
#  ('/satomacoto',): 0,
#  ('/mikeskim',): 0,
#  ('/autostrat',): 0,
#  ('/wojciechmigda',): 0,
#  ('/pmduarte',): 0,
#  ('/gemunu',): 0,
#  ('/cgratie',): 0,
#  ('/ceciliat',): 0,
#  ('/santanub',): 0,
#  ('/pritipatra',): 0,
#  ('/ojasvi',): 0,
#  ('/bhatth05',): 0,
#  ('/stouzani',): 0,
#  ('/cladier',): 0,
#  ('/liableminer',): 0,
#  ('/krishnakesavan',): 0,
#  ('/kilimnik',): 0,
#  ('/randompulse',): 0,
#  ('/ngaffney',): 0,
#  ('/gilmar2013',): 0,
#  ('/testhaha',): 0,
#  ('/farouktangao',): 0,
#  ('/vinhkhuc',): 0,
#  ('/scsmith2',): 0,
#  ('/dougkoch',): 0,
#  ('/phrendille',): 0,
#  ('/epinephelus',): 0,
#  ('/charlesroberson',): 0,
#  ('/tommontroy',): 0,
#  ('/jimmyxu',): 0,
#  ('/esperto007',): 0,
#  ('/manels',): 0,
#  ('/cbourne',): 0,
#  ('/majhra',): 0,
#  ('/negwest1',): 0,
#  ('/kashyapu',): 0,
#  ('/goalminer',): 0,
#  ('/saurabhkansal',): 0,
#  ('/lolpig',): 0,
#  ('/dlajeunesse',): 0,
#  ('/lysisza',): 0,
#  ('/uditsaini',): 0,
#  ('/gofordream',): 0,
#  ('/rohanrao',): 0,
#  ('/brianbai',): 0,
#  ('/johanmanders',): 0,
#  ('/tgalina',): 0,
#  ('/bgeier',): 0,
#  ('/draken',): 0,
#  ('/yuvraj',): 0,
#  ('/khrapal',): 0,
#  ('/fernandoprocy',): 0,
#  ('/mukundhingne',): 0,
#  ('/kwartler',): 0,
#  ('/dadou46',): 0,
#  ('/deidei',): 0,
#  ('/neuro17',): 0,
#  ('/kbartol',): 0,
#  ('/achursov',): 0,
#  ('/lucienderubempre',): 0,
#  ('/jeongyoonlee',): 0,
#  ('/anthonyp',): 0,
#  ('/alexsmith21',): 0,
#  ('/del=981949bcab6a4072',): 0,
#  ('/m4ch1n3',): 0,
#  ('/alexlzzz',): 0,
#  ('/mconway',): 0,
#  ('/juvleo',): 0,
#  ('/xingwei',): 0,
#  ('/anilkumar469',): 0,
#  ('/anjanaagrawal',): 0,
#  ('/indradenbakker',): 0,
#  ('/rybick',): 0,
#  ('/johnxllis',): 0,
#  ('/dominique',): 0,
#  ('/fcastanedo',): 0,
#  ('/mingshan',): 0,
#  ('/shenwenlong',): 0,
#  ('/armaseg',): 0,
#  ('/gracegimon',): 0,
#  ('/ctrabuco',): 0,
#  ('/sdrapak',): 0,
#  ('/nilotpal',): 0,
#  ('/bosukh',): 0,
#  ('/codebender',): 0,
#  ('/sergiorivera',): 0,
#  ('/domashnev',): 0,
#  ('/michaelpawlus',): 0,
#  ('/usixuz',): 0,
#  ('/srikiyer',): 0,
#  ('/mattvonrohr',): 0,
#  ('/njuysen',): 0,
#  ('/janekk',): 0,
#  ('/apsgiles',): 0,
#  ('/benjamwhite',): 0,
#  ('/jiaqianqian',): 0,
#  ('/xiaolaoshu',): 0,
#  ('/zaxcie',): 0,
#  ('/fernandoconstantino',): 0,
#  ('/instigator',): 0,
#  ('/ghellstern',): 0,
#  ...}

# %%
nx.hits(G)
# Out:
# ({6004: 5.694081061271699e-06,
#   4699: 5.1793637582674784e-05,
#   4571: 5.183503374965881e-06,
#   4657: 4.079792643959775e-05,
#   4494: 1.0989957134051187e-06,
#   4504: 1.9745007105779508e-05,
#   4704: 2.516408186691169e-05,
#   4521: 8.579356700586533e-06,
#   4594: 5.8852104279016884e-05,
#   4523: 1.828173420123399e-06,
#   4487: 4.406301484265026e-05,
#   4493: 8.160177849133249e-06,
#   4488: 1.9209719147413124e-05,
#   4481: 2.4844415700545592e-05,
#   4467: 2.9073402595366584e-05,
#   4471: 4.2666692373080155e-05,
#   4453: 1.0288258075447277e-05,
#   4438: 1.2829941931104726e-05,
#   4104: 1.091231153875658e-05,
#   4407: 2.6646421442369154e-05,
#   4366: 2.6067625158330383e-05,
#   4280: 4.7989437522907726e-05,
#   4272: 3.384432008990194e-05,
#   4066: 4.955744342476865e-06,
#   3978: 1.5166471746420555e-05,
#   4031: 1.9378864738862307e-05,
#   4120: 1.9829416756968046e-05,
#   3973: 8.27009086261125e-06,
#   3984: 9.282879747106143e-06,
#   3887: 1.761848000144824e-05,
#   3951: 1.1234228342627033e-05,
#   3929: 4.41004697831524e-06,
#   3897: 1.0114756504867796e-05,
#   3778: 1.1440653262405637e-06,
#   3788: 1.6151425692268767e-05,
#   3706: 1.789439934861884e-06,
#   3867: 3.5920539656444714e-06,
#   3757: 1.1257568114203969e-06,
#   3670: 3.689653831268871e-06,
#   3532: 1.783316675266136e-06,
#   3618: 6.52420672688066e-07,
#   3599: 5.025074845236342e-06,
#   3504: 3.8032480759877254e-06,
#   3526: 6.239886661633983e-06,
#   2969: 2.402826042304305e-06,
#   3403: 1.143085670044974e-06,
#   3525: 1.6220046071536182e-07,
#   3338: 1.0676103309183308e-05,
#   3445: 2.178145122994104e-06,
#   3446: 1.7432359106986028e-06,
#   3493: 1.457717637562763e-06,
#   3316: 4.014336402788392e-06,
#   3469: 1.5793034752448163e-06,
#   3353: 1.7345719103907622e-06,
#   2496: 4.751005546834116e-06,
#   3342: 2.8303577276550454e-06,
#   3288: 1.4351817090612086e-06,
#   3294: 3.0492830081406362e-06,
#   3108: 1.3959302637148916e-06,
#   3043: 7.375440835098746e-07,
#   2975: 2.3836306356349852e-06,
#   2863: 2.1786822888551475e-07,
#   2963: 1.3084830105699785e-06,
#   2840: 2.7415893023571782e-06,
#   2780: 3.895356485555442e-06,
#   2748: 7.934476394197313e-07,
#   2749: 3.874713008836149e-07,
#   2667: 6.01680702132362e-07,
#   2732: 1.1882539131481439e-06,
#   2889: 5.479502982496551e-07,
#   2602: 2.2516858172400883e-07,
#   2606: 1.0985317040981486e-06,
#   3321: 0.0,
#   2589: 6.630665183296264e-07,
#   2564: 2.1604186995732607e-06,
#   2551: 2.8619830150324865e-06,
#   2609: 1.1432774381632436e-06,
#   2549: 4.852265068428131e-08,
#   2509: 5.525309123486469e-07,
#   2518: 1.070398627347202e-06,
#   2499: 1.909638204747919e-07,
#   2487: 5.173172182187351e-07,
#   2489: 1.0328002572726604e-06,
#   2479: 4.901572861228102e-07,
#   2488: 2.9513260584113806e-08,
#   2478: 5.907272315120885e-07,
#   2445: 6.559946773724745e-07,
#   2467: 4.1299893769839927e-07,
#   2454: 2.1248179822536986e-07,
#   2464: 2.741134000844366e-07,
#   2452: 2.2161199163972333e-07,
#   2447: 4.871924888590952e-07,
#   2439: 2.2258495748997212e-07,
#   2448: 1.620973153984903e-07,
#   2435: 2.654830815504272e-07,
#   2438: 0.0,
#   2442: 3.580179406483465e-08,
#   2408: 8.831982696601666e-10,
#   5558: 3.197368699949269e-05,
#   5357: 2.6931011926925834e-05,
#   5261: 4.5706863217558075e-05,
#   5340: 3.219184581951902e-05,
#   5260: 3.8279709881351744e-05,
#   5144: 1.965287668612886e-05,
#   5048: 2.646228713269698e-05,
#   5174: 1.751883974377704e-05,
#   5229: 1.4958249779843698e-05,
#   5056: 4.2488683899715265e-05,
#   4986: 8.50935950280948e-05,
#   4853: 3.978308956228412e-05,
#   4852: 5.750495664823285e-05,
#   4862: 1.3792243467901804e-05,
#   4729: 5.021601080544827e-06,
#   5497: 1.8853822453693854e-05,
#   5916: 1.1447234182182727e-05,
#   5874: 2.9293331644606775e-05,
#   5390: 9.031480939687168e-06,
#   6116: 9.706312662653656e-06,
#   6243: 5.590828046323605e-06,
#   6277: 4.2820938934528536e-05,
#   6049: 1.0359795091419609e-05,
#   5568: 7.391475930074888e-06,
#   6644: 4.241010098839375e-05,
#   6322: 1.4787187267438001e-05,
#   6565: 5.935337670817916e-05,
#   6392: 5.013943515538121e-05,
#   6649: 4.96341658690887e-05,
#   6775: 2.9613431034484e-06,
#   7115: 1.0999862270802826e-05,
#   7082: 7.350233349701328e-05,
#   6927: 1.3471884444704535e-05,
#   7391: 2.8604093773622225e-05,
#   7634: 1.5400692900910634e-05,
#   7559: 3.209825260596603e-05,
#   8078: 1.0863263890819716e-05,
#   7277: 3.30716661879112e-05,
#   7380: 3.560232466291759e-05,
#   9949: 8.222733024029554e-06,
#   9951: 6.152974718808917e-06,
#   9120: 8.601979833477497e-05,
#   9717: 5.5874202538087803e-05,
#   7878: 1.3176079045565367e-05,
#   9301: 6.091919955343253e-06,
#   8586: 2.793955051886189e-05,
#   8540: 5.0438681730461085e-05,
#   8089: 8.69808508624422e-06,
#   8310: 8.531351911175129e-06,
#   8311: 7.240326650043397e-06,
#   8076: 5.282560593007179e-05,
#   ('/badrobot', '/grt123', '/liaofz'): 1.0256286459806264e-06,
#   ('/dhammack', '/juliandewit'): 2.9911748311290325e-06,
#   ('/gerbenvv', '/markjan', '/timsalimans'): 1.0256286459806264e-06,
#   ('/jdingpku',
#    '/jiabao',
#    '/jiayuangu',
#    '/lax123',
#    '/pkuhuzq',
#    '/stevegaopku',
#    '/wanglw',
#    '/xyq676419'): 1.0256286459806264e-06,
#   ('/pfillard',): 1.0256286459806264e-06,
#   ('/georges', '/transcranial'): 1.9301289264369323e-06,
#   ('/falexwolf',
#    '/julianjungwirth',
#    '/m2dao2dar',
#    '/niklaskoehler'): 1.0256286459806264e-06,
#   ('/alexryzhkov', '/andrem', '/sushize', '/titericz'): 1.0256286459806264e-06,
#   ('/de317070',
#    '/fgodin',
#    '/gabs48',
#    '/golondrina',
#    '/jburms',
#    '/lpigou',
#    '/resivium',
#    '/sailenav',
#    '/tnneuten',
#    '/x141d68f'): 1.0256286459806264e-06,
#   ('/nhlx5haze', '/simjeg'): 1.0256286459806264e-06,
#   ('/aguschin',
#    '/dulyanov',
#    '/mikhailtrofimov',
#    '/utility'): 1.0256286459806264e-06,
#   ('/danielfg',): 0.00010435647596677554,
#   ('/alexch',): 2.818152114736872e-05,
#   ('/fengxy', '/wanwanbeen'): 1.0256286459806264e-06,
#   ('/romualdj',): 4.575498685541757e-05,
#   ('/aaalgo', '/gyuanfan'): 3.4968444567733513e-06,
#   ('/cojocchen',
#    '/famousboy',
#    '/junjiebai',
#    '/kagglemonkey',
#    '/songq03'): 1.0256286459806264e-06,
#   ('/jacobkie',): 1.947115272130181e-05,
#   ('/anlthms', '/shaironen'): 1.0256286459806264e-06,
#   ('/jingchenma',): 1.0256286459806264e-06,
#   ('/ccc4321',): 1.0256286459806264e-06,
#   ('/zhipengjia',): 1.0256286459806264e-06,
#   ('/chirag1992m',
#    '/jzbontar',
#    '/kjgeras',
#    '/peilunz',
#    '/yichen'): 1.0256286459806264e-06,
#   ('/zeliek',): 2.3181182511056375e-05,
#   ('/mumech',): 4.4216147913486e-06,
#   ('/bipling',): 1.0256286459806264e-06,
#   ('/alxvoropaev',
#    '/bernadsky',
#    '/lukaoo',
#    '/quantum13'): 1.0256286459806264e-06,
#   ('/dejianli', '/tiankongdeguiji'): 1.0256286459806264e-06,
#   ('/kenjung',): 1.0256286459806264e-06,
#   ('/nitaidean', '/urimerhav'): 1.0256286459806264e-06,
#   ('/evikop',
#    '/guyeng',
#    '/hadarpo',
#    '/hggshntr',
#    '/tiferet'): 1.0256286459806264e-06,
#   ('/pittzzll', '/zhennany'): 1.0256286459806264e-06,
#   ('/u39kun',): 5.229558009465798e-06,
#   ('/azureparrot',
#    '/carlosgr',
#    '/consumes',
#    '/felixgimeno',
#    '/jacoboaj',
#    '/jorditura',
#    '/josecordero',
#    '/martimayo',
#    '/mingot',
#    '/mteixido',
#    '/ricarddelgado'): 1.0256286459806264e-06,
#   ('/gtgtgt',
#    '/kyoungjin',
#    '/member',
#    '/myunggilee',
#    '/sjson718'): 1.0256286459806264e-06,
#   ('/ficusrong', '/purpleslz'): 1.0256286459806264e-06,
#   ('/hamidehhs',): 1.0256286459806264e-06,
#   ('/zfturbo',): 0.00023868624394127955,
#   ('/jiweiliu',): 0.00014040291262955854,
#   ('/lindaseok', '/ykwon0407'): 1.0256286459806264e-06,
#   ('/nuszeng',): 1.635284786015646e-05,
#   ('/alsrgv',): 1.8824063670949187e-05,
#   ('/woshialex',): 0.000109436009141931,
#   ('/basveeling',
#    '/binyam',
#    '/dimitriosm',
#    '/jrubin',
#    '/swishswish',
#    '/tstojan'): 1.0256286459806264e-06,
#   ('/mchahhou', '/nimashahbazi'): 3.2895831076940295e-05,
#   ('/dustodust', '/ecopoiesis'): 1.0256286459806264e-06,
#   ('/peterchang77', '/simi09'): 1.0256286459806264e-06,
#   ('/danielrk',): 1.0256286459806264e-06,
#   ('/deepimagine',): 3.8350698810315465e-05,
#   ('/aizvorski', '/hantah'): 1.0256286459806264e-06,
#   ('/abdulwahabkabani',): 3.783348762608255e-05,
#   ('/savvok',): 1.2361481196368566e-05,
#   ('/tomascernik', '/tondracek', '/tpacko'): 1.0256286459806264e-06,
#   ('/sarkadiu',): 4.429438617321556e-05,
#   ('/eyalis',): 2.9433938265875446e-05,
#   ('/qingnan',): 4.241422545788432e-05,
#   ('/junshi',): 8.87383048184634e-05,
#   ('/dstahlke', '/pratkar', '/saumyadip'): 1.0256286459806264e-06,
#   ('/cordsters',
#    '/dbroadhead',
#    '/dplavery92',
#    '/langbw'): 1.0256286459806264e-06,
#   ('/guiber',): 3.452209942098716e-06,
#   ('/fvelickovski', '/xrafael'): 1.0256286459806264e-06,
#   ('/flyerscan1',): 1.0256286459806264e-06,
#   ('/macmadman',): 1.0256286459806264e-06,
#   ('/pangyuteng',): 1.0256286459806264e-06,
#   ('/zetaochen',): 1.0256286459806264e-06,
#   ('/victorsd',): 0.0001007085651723192,
#   ('/symyksr',): 0.0001557286616039399,
#   ('/nedelko',): 0.0002476398475660241,
#   ('/carrendd',): 1.0256286459806264e-06,
#   ('/louisf',): 1.9301289264369323e-06,
#   ('/huxiaowei',): 1.0256286459806264e-06,
#   ('/goldendomer', '/topdps'): 1.0256286459806264e-06,
#   ('/ctsats', '/ouranos', '/voglinio'): 2.3569952648233552e-06,
#   ('/carryzhuzhu',): 1.0256286459806264e-06,
#   ('/bihanchristy', '/microljy'): 1.0256286459806264e-06,
#   ('/adityakumarsinha', '/lingcenfan', '/salkaa'): 1.0256286459806264e-06,
#   ('/happyjoe',): 1.0256286459806264e-06,
#   ('/londalemex',): 1.7116643595686334e-05,
#   ('/rasdmla',): 1.0256286459806264e-06,
#   ('/ofnovember', '/savfod'): 1.0256286459806264e-06,
#   ('/binarychan',): 1.0256286459806264e-06,
#   ('/bmcinnovo',): 8.189627783945491e-05,
#   ('/ahkobayashi', '/mtfall'): 1.0256286459806264e-06,
#   ('/johngull', '/qubyxsw', '/ramzes2'): 1.0256286459806264e-06,
#   ('/jarrelscy',): 1.0256286459806264e-06,
#   ('/abriosi', '/del=c16e54e8d82063ca', '/sickocell'): 1.0256286459806264e-06,
#   ('/supersummer',): 1.0256286459806264e-06,
#   ('/keunho', '/mklim82'): 1.0256286459806264e-06,
#   ('/yijunliu',): 1.0256286459806264e-06,
#   ('/chucktown', '/hparks', '/mels630', '/sm1011'): 1.0256286459806264e-06,
#   ('/bluesky',): 4.418717580959431e-05,
#   ('/yshrestha',): 3.452209942098716e-06,
#   ('/rluethy',): 8.541679787411512e-05,
#   ('/scottykwok',): 2.8512119964734145e-05,
#   ('/snezhko',): 1.0256286459806264e-06,
#   ('/zuchunshan',): 1.0256286459806264e-06,
#   ('/adrianmelic',
#    '/ajulian',
#    '/javiertag',
#    '/virilo'): 1.0256286459806264e-06,
#   ('/parkinsonzabelin',): 0.00012724441354394398,
#   ('/qradiomics',): 1.0256286459806264e-06,
#   ('/heypeter',): 7.199804178478594e-05,
#   ('/ashish9',
#    '/cr2015',
#    '/csgwon',
#    '/elvientowjf',
#    '/jtutmaher',
#    '/tangerine007'): 1.0256286459806264e-06,
#   ('/sekrier',): 0.00017227369994309098,
#   ('/miguelpm',): 0.000150422192521756,
#   ('/pszoldan',): 1.0256286459806264e-06,
#   ('/clarkchong',): 2.0424261886131114e-05,
#   ('/zacharydestefano',): 8.664616216533274e-06,
#   ('/zephyrd',): 4.9669594323650435e-05,
#   ('/illidan7',): 6.301998923741961e-06,
#   ('/mathurinache',): 0.00023868141243251544,
#   ('/abnera',): 1.0256286459806264e-06,
#   ('/yourwanghao',): 2.7400241503843862e-05,
#   ('/ywkim22',): 1.0256286459806264e-06,
#   ('/opanichev',): 0.00011094428196979598,
#   ('/ceshine',): 0.00032455967121752463,
#   ('/julesvanligtenberg',): 0.00022201073111513214,
#   ('/dmatwork',
#    '/prajak',
#    '/saptarc',
#    '/shakul20',
#    '/thearchitect'): 1.0256286459806264e-06,
#   ('/svesal',): 8.891773544025415e-05,
#   ('/askelpian', '/kbl4ew', '/srrobert50'): 1.0256286459806264e-06,
#   ('/watts2',): 6.225283029096433e-05,
#   ('/isaacmg',): 3.307625012770584e-05,
#   ('/albertyho',
#    '/kunhsingyu',
#    '/lckung',
#    '/samcc0815'): 1.0256286459806264e-06,
#   ('/evgluk',): 1.32054192207689e-05,
#   ('/klyusba',): 1.4907703283762723e-05,
#   ('/jpmiller',): 0.0002929371989612158,
#   ('/patripen26',): 1.0256286459806264e-06,
#   ('/shuangliu',): 1.0256286459806264e-06,
#   ('/marek3000',): 0.0001426693261944217,
#   ('/clustifier',): 0.00027163334963005697,
#   ('/captaindadja',): 7.633619989551558e-05,
#   ('/ekonev', '/ilyaaln'): 1.0256286459806264e-06,
#   ('/legion007',): 1.0256286459806264e-06,
#   ('/roma141', '/senenbotello'): 8.738617124098592e-06,
#   ('/aaberlin',
#    '/ahmedhosny',
#    '/bgwoodward',
#    '/chintanparmar',
#    '/haerts',
#    '/hexacore',
#    '/oozdemir'): 1.0256286459806264e-06,
#   ('/sanderdalm',): 1.4477226849857072e-05,
#   ('/josgilby',): 2.7739480335244763e-06,
#   ('/agavranis',): 0.00026270483993979176,
#   ('/etheleon', '/neoanarika'): 1.0256286459806264e-06,
#   ('/felmans', '/huntleym', '/khriswang', '/lucashu'): 1.0256286459806264e-06,
#   ('/kevinsoucy', '/lars5k', '/rivalmuc'): 1.0256286459806264e-06,
#   ('/paula27121990',): 1.0256286459806264e-06,
#   ('/linhaili',): 6.301998923741961e-06,
#   ('/vicensgaitan',): 0.0002136146548036355,
#   ('/forensics409',): 1.2107392188583634e-05,
#   ('/hengjianjia',): 1.0256286459806264e-06,
#   ('/danelb',
#    '/meniam',
#    '/nadavl',
#    '/nelzas',
#    '/nslonim',
#    '/veredfish'): 1.0256286459806264e-06,
#   ('/finalbad860822',
#    '/kisara',
#    '/liweifeng',
#    '/lunaguan'): 1.0256286459806264e-06,
#   ('/arturscussel',
#    '/escudero',
#    '/pedrohaamorim',
#    '/silviomoreto'): 1.0256286459806264e-06,
#   ('/awakebacker',
#    '/chen121',
#    '/graydlpnwedu',
#    '/tomath1'): 1.0256286459806264e-06,
#   ('/marksalacinski',): 1.0256286459806264e-06,
#   ('/miguel777',): 1.703900984086204e-05,
#   ('/joaopoliveira', '/jongomez'): 1.0256286459806264e-06,
#   ('/deepbraineu', '/fabriziodefausti'): 1.0256286459806264e-06,
#   ('/mikell',): 5.8451637192737206e-05,
#   ('/erwanlc',): 1.0256286459806264e-06,
#   ('/eduardoli',): 0.0001234229624499401,
#   ('/bodorin',): 1.0256286459806264e-06,
#   ('/semiquark1',): 1.0753421591912052e-05,
#   ('/ashayshah7',): 1.0256286459806264e-06,
#   ('/gefrix',): 1.0256286459806264e-06,
#   ('/caoxiaoqing',): 1.0256286459806264e-06,
#   ('/linbo2016',): 1.559031364487808e-06,
#   ('/dlevashov', '/mshytikov'): 1.0256286459806264e-06,
#   ('/ibhandar', '/mpapadopulos'): 1.0256286459806264e-06,
#   ('/mindcool',): 0.00019045579212649967,
#   ('/laroumagne',): 7.364088101147339e-05,
#   ('/jekyllsmith',): 0.00012439247821785,
#   ('/katharineruoxi', '/stevenliuyi'): 1.0256286459806264e-06,
#   ('/bingqingzhang',
#    '/jstzhyd',
#    '/shsnail',
#    '/thebear123'): 1.0256286459806264e-06,
#   ('/kambarakun',): 3.567351410221336e-05,
#   ('/ronoliverocs',): 3.398928914368358e-06,
#   ('/mfrank',): 7.062038778339192e-05,
#   ('/dmayeda',): 1.0256286459806264e-06,
#   ('/sadz2201',): 0.00022050312945773033,
#   ('/alijs1',): 0.0001566016601866598,
#   ('/ankasor',): 2.032659163699984e-06,
#   ('/cgratie', '/lvaleriu'): 8.738617124098592e-06,
#   ('/janosk21',): 0.00027982028940659365,
#   ('/madhurgoel',): 8.664616216533274e-06,
#   ('/garethjns',): 8.299688514500749e-05,
#   ('/heathmccasland', '/jacobdeecurtis'): 1.0256286459806264e-06,
#   ('/harwester',): 4.048055520508475e-05,
#   ('/ronpatrick',): 1.0256286459806264e-06,
#   ('/joe1987',): 1.0256286459806264e-06,
#   ('/mlu821',): 1.0256286459806264e-06,
#   ('/ecentury',): 1.0256286459806264e-06,
#   ('/alanlnguyen',
#    '/cfried123',
#    '/ericabrauer',
#    '/hatfieldm48',
#    '/hollifieldzachary',
#    '/joshbaker',
#    '/ldcolosi',
#    '/mjbrienza',
#    '/penguinskid',
#    '/soniahinson',
#    '/znuzzo'): 1.0256286459806264e-06,
#   ('/amalhotra', '/jsardinha'): 3.452209942098716e-06,
#   ('/woomky',): 1.0256286459806264e-06,
#   ('/anokas',): 0.00019275815432910008,
#   ('/sidharthkumar',): 5.376135363755079e-05,
#   ('/meganwang',
#    '/mikesitu',
#    '/nicozheng',
#    '/w52918',
#    '/yanyang729'): 1.0256286459806264e-06,
#   ('/kwarner',): 1.0256286459806264e-06,
#   ('/drc10723',): 1.0540676658247215e-05,
#   ('/gshaham',): 1.0256286459806264e-06,
#   ('/dxchen',): 1.0256286459806264e-06,
#   ('/ekkus93',): 2.4637324457997224e-05,
#   ('/rdebbe',): 3.71329599894032e-05,
#   ('/lucamassaron',): 0.0002123772753756072,
#   ('/probe301',): 9.965828440659843e-06,
#   ('/jhs1728',): 8.738617124098592e-06,
#   ('/amanrana20',): 1.5112275541602339e-05,
#   ('/hskksk',): 1.5563646738938926e-05,
#   ('/akoriagin',
#    '/dearkafka',
#    '/kirillemilio',
#    '/podviaznikoff'): 1.0256286459806264e-06,
#   ('/annuuusaxena',
#    '/garchrs',
#    '/outliar',
#    '/rangerdavis',
#    '/shivangbaijal'): 1.0256286459806264e-06,
#   ('/mochiliu', '/sleepywyn'): 1.0256286459806264e-06,
#   ('/jordimas',): 1.0256286459806264e-06,
#   ('/jiuxu1987', '/murocks', '/parkerzf', '/xywangcs'): 1.0256286459806264e-06,
#   ('/jaleto',): 1.6929789997451618e-05,
#   ('/craigglastonbury', '/kirk86', '/wrosinski'): 1.0256286459806264e-06,
#   ('/lyapinnr',): 4.129826016767893e-05,
#   ('/praveenadepu',): 0.00015322024857037509,
#   ('/clavichord93',): 1.0256286459806264e-06,
#   ('/oraculseed',): 4.3328042680242217e-05,
#   ('/jaybob20',): 0.0001664508041500941,
#   ('/mcasshy',): 7.065207483775801e-05,
#   ('/del=2fcc0575facc0452',
#    '/michaelxiao',
#    '/posiedon',
#    '/tonygao'): 1.0256286459806264e-06,
#   ('/aastalin', '/tungty'): 1.1635654381733948e-05,
#   ('/jbrasher6', '/rrp9999'): 1.0256286459806264e-06,
#   ('/dhegde',): 0.00015941692980394134,
#   ('/hidy0503', '/mdsfdwei1'): 7.438386674031784e-06,
#   ('/edelbert', '/gabidentanekeev'): 1.0256286459806264e-06,
#   ('/mstrhw',): 3.452209942098716e-06,
#   ('/cyllyue',
#    '/iridescent',
#    '/jiangqy',
#    '/jingyou2017'): 1.0256286459806264e-06,
#   ('/lolitacoder',): 1.0256286459806264e-06,
#   ('/jakublangr', '/pavan4'): 1.0256286459806264e-06,
#   ('/niallm',): 1.1852244646316203e-05,
#   ('/hewang',
#    '/kentsyx',
#    '/lihuiminphd',
#    '/namasamita',
#    '/ozzzzzp',
#    '/qiangfd',
#    '/ronniezhou'): 1.0256286459806264e-06,
#   ('/cpmpml',
#    '/datasciencekrk',
#    '/elliotw',
#    '/lukaszcmielowski'): 1.0256286459806264e-06,
#   ('/lucy00', '/nanisbad'): 1.0256286459806264e-06,
#   ('/zhangxiaoya1993',): 1.0256286459806264e-06,
#   ('/rdcolema',): 3.270619111321431e-05,
#   ('/maciejv',): 4.3918923050924475e-05,
#   ('/andrewszot',
#    '/arthurshau',
#    '/harshipr',
#    '/rachitkataria',
#    '/yunalee22'): 1.0256286459806264e-06,
#   ('/astaria',
#    '/chpark',
#    '/dyaprk',
#    '/keeyoung',
#    '/kwanghee',
#    '/pubmed'): 1.0256286459806264e-06,
#   ('/lamthuy',): 1.0256286459806264e-06,
#   ('/medial',): 7.950157485641952e-05,
#   ('/dev7il',
#    '/gberinger',
#    '/jpowierza',
#    '/kryhebel',
#    '/maciejbudys',
#    '/matjabl',
#    '/nordberdt',
#    '/paluchowskid'): 1.0256286459806264e-06,
#   ('/shaziatoronto', '/sylvesterchiang'): 1.0256286459806264e-06,
#   ('/jeffhebert',): 0.0002885240644240804,
#   ('/ic3fr0g',
#    '/manrajsingh',
#    '/rmanuuu',
#    '/shamssam'): 1.0256286459806264e-06,
#   ('/lizhen3201',): 1.0256286459806264e-06,
#   ('/eduzznet',): 0.00010592167614409485,
#   ('/ggggfan',): 3.075848399784991e-05,
#   ('/clover9gu',): 1.0256286459806264e-06,
#   ('/applejus',): 2.691900701668875e-05,
#   ('/del=bb3a2820312ac701',): 1.0256286459806264e-06,
#   ('/danieleewww',): 0.0001392247380709426,
#   ('/andyqiu', '/anuar12', '/chengxie', '/schorlem'): 1.0256286459806264e-06,
#   ('/ampires', '/jbranco'): 6.95816889705712e-05,
#   ('/ernestyalumni',): 1.4265007919002603e-05,
#   ('/maplelin', '/ycsos0'): 1.0256286459806264e-06,
#   ('/phawishi',): 1.0256286459806264e-06,
#   ('/sambitnandi',): 1.0256286459806264e-06,
#   ('/ryutek',): 0.00033142285896547313,
#   ('/chalfacre',): 8.820173775887555e-05,
#   ('/kaggle4mayank',): 1.0256286459806264e-06,
#   ('/ivanl1',): 4.290112226375699e-05,
#   ('/anilhk', '/muralimnk'): 1.0256286459806264e-06,
#   ('/alesgb', '/andreikaralkou', '/orkenstein'): 1.0256286459806264e-06,
#   ('/wakeup06',): 4.2953587171680865e-05,
#   ('/rocelot',): 6.606958287745983e-05,
#   ('/ttucphares', '/tturubie'): 1.0256286459806264e-06,
#   ('/enriquebalp',): 1.0256286459806264e-06,
#   ('/bioruben', '/masreal'): 1.0256286459806264e-06,
#   ('/bhillmann',): 1.0256286459806264e-06,
#   ('/esuerid', '/junharin', '/kihwan'): 1.0256286459806264e-06,
#   ('/yunkyong',): 2.4212238231401177e-05,
#   ('/fskidmore', '/godaibo', '/thomasal'): 1.0256286459806264e-06,
#   ('/psaadbye',): 3.0842967759352344e-05,
#   ('/filareta',): 1.0256286459806264e-06,
#   ('/aijiang', '/lszhang'): 3.764469753155797e-05,
#   ('/del=121b7398bccb8e5a',): 0.00022469320156012242,
#   ('/asonora',
#    '/bjansen',
#    '/epapavas',
#    '/lomelina',
#    '/panosgon'): 1.0256286459806264e-06,
#   ('/terravic',): 1.0256286459806264e-06,
#   ('/whukui',): 1.0256286459806264e-06,
#   ('/thekokonuts',): 2.3701923952308572e-05,
#   ('/willieliao',): 0.0002492739949130709,
#   ('/dimasakovich',
#    '/josemarcosrf',
#    '/kostidov',
#    '/shevva'): 1.0256286459806264e-06,
#   ('/gaurav705362', '/ttus09'): 1.0256286459806264e-06,
#   ('/igorkrashenyi',): 5.1915119030398405e-05,
#   ('/north1605', '/wezemer'): 1.0256286459806264e-06,
#   ('/parthassatpathy', '/rashmitarouy01'): 1.0256286459806264e-06,
#   ('/potatoface',): 1.0256286459806264e-06,
#   ('/samxie',): 1.0256286459806264e-06,
#   ('/tunguz',): 0.0002362196492897341,
#   ('/rodenluo',): 1.1635123046439765e-05,
#   ('/atuljjoshi05',): 1.1716471072122214e-05,
#   ('/paulorzp',): 0.00023600669022583054,
#   ('/indianotaku', '/saigouthamttu'): 1.0256286459806264e-06,
#   ('/vbardiovsky',): 2.2986412718144128e-05,
#   ('/chipmonkey',): 0.0002779323090183913,
#   ('/olivierc',): 1.0256286459806264e-06,
#   ('/agrawroh',
#    '/jeremyxtq',
#    '/thepratik',
#    '/wenjun93'): 1.0256286459806264e-06,
#   ('/nhargan',): 7.507510790506465e-05,
#   ('/shleedynamics',): 1.4368845103747174e-05,
#   ('/boleszek',): 1.0256286459806264e-06,
#   ('/wzwrwjbsy',): 4.3241414301728085e-05,
#   ('/nvpiao',): 1.0256286459806264e-06,
#   ('/georgiaphi1389', '/msugimura', '/rhaughey'): 1.0256286459806264e-06,
#   ('/wcukierski',): 0.00016733454812755243,
#   ('/ascreven',
#    '/daewoo',
#    '/fanc5804',
#    '/jackbarry',
#    '/karibdo',
#    '/lusevier',
#    '/maddiemesard',
#    '/realviacauchy'): 1.0256286459806264e-06,
#   ('/alexeylive',): 0.000113562583030581,
#   ('/carloshuertas',): 0.0003102596199122432,
#   ('/jzima7',): 2.223375161447375e-05,
#   ('/luoyuxuanlyx',): 1.6519677351323684e-05,
#   ('/nenezhu', '/yuanrong'): 1.0256286459806264e-06,
#   ('/slonoslon',): 5.370087475133545e-05,
#   ('/niranjanmudhiraj',): 0.00026740198358530534,
#   ('/szalmaf', '/ungsur'): 1.0256286459806264e-06,
#   ('/pradnyachahande', '/ttumax'): 1.0256286459806264e-06,
#   ('/muhammedazamkhan',): 9.331276595907598e-05,
#   ('/cotouk',): 1.4564152952265887e-05,
#   ('/vetribox',): 0.0001431718258348193,
#   ('/cominger', '/davinnovation'): 1.0256286459806264e-06,
#   ('/pedram',): 4.4036159609414e-05,
#   ('/kevin0319',): 1.0256286459806264e-06,
#   ('/barrettxav',): 1.0256286459806264e-06,
#   ('/spacepizza',): 1.0256286459806264e-06,
#   ('/vihangpatil',): 1.3138909783700636e-05,
#   ('/yatsura',): 1.0256286459806264e-06,
#   ('/engenious',): 0.00026528666265627533,
#   ('/abhikapoor',
#    '/akashshrivastava0406',
#    '/sahilsharma'): 1.0256286459806264e-06,
#   ('/fahd09',): 1.0256286459806264e-06,
#   ('/abhisek2204',
#    '/birupakhya',
#    '/mayukhss',
#    '/saroj4kaggle'): 1.0256286459806264e-06,
#   ('/lawrencechernin',): 0.0003687871499112177,
#   ('/baoxiangyang',
#    '/haoyuz',
#    '/huili93',
#    '/osake218'): 1.0256286459806264e-06,
#   ('/zongweimayo',): 1.0256286459806264e-06,
#   ('/abqazi', '/sdbttu'): 1.0256286459806264e-06,
#   ('/seemakanuri', '/ttusuresh'): 1.0256286459806264e-06,
#   ('/dwjwlxs',): 1.0256286459806264e-06,
#   ('/coroscop',): 1.0256286459806264e-06,
#   ('/isyebojiang',
#    '/jcausey',
#    '/jyzang',
#    '/nodulesuperx',
#    '/qualls',
#    '/shiqian',
#    '/shuzhong'): 1.0256286459806264e-06,
#   ('/krishnateja614',): 0.00011044854687644483,
#   ('/timon88',): 6.739890232476323e-05,
#   ('/akuman',
#    '/panditshreya',
#    '/xidexia',
#    '/xinye1115'): 1.0256286459806264e-06,
#   ('/rehband',): 2.461139308476664e-05,
#   ('/alextlin',): 1.0256286459806264e-06,
#   ('/tangshouquan',): 1.1716471072122214e-05,
#   ('/grittyy',): 1.0256286459806264e-06,
#   ('/heryson', '/oliphilip', '/vdouetvannucci'): 1.0256286459806264e-06,
#   ('/ernie55ernie',): 1.0256286459806264e-06,
#   ('/acmh360',
#    '/andreabduque',
#    '/arturfranco',
#    '/bezerra',
#    '/brielmachado',
#    '/caminha',
#    '/castilho',
#    '/cstiano',
#    '/djeefther',
#    '/jbsn90',
#    '/larissalages',
#    '/lucasveloso',
#    '/marilugomes',
#    '/nataliakitaoka',
#    '/nilsonlima',
#    '/renatosousa',
#    '/thiagovicente',
#    '/viniciussanguinete',
#    '/wellpin'): 1.0256286459806264e-06,
#   ('/rats001',): 1.0256286459806264e-06,
#   ('/vlarine',): 0.00029693697903453083,
#   ('/feiyun',
#    '/kumargayu',
#    '/minhazul',
#    '/shengwa',
#    '/utayao',
#    '/xinliangzhu'): 1.0256286459806264e-06,
#   ('/elsa123',): 1.0256286459806264e-06,
#   ('/ferpalaciosugr',): 5.792065833860505e-06,
#   ('/rjbashar',): 2.8916545240640314e-06,
#   ('/xyzeng',): 1.0256286459806264e-06,
#   ('/joshuaw', '/timbacy'): 1.0256286459806264e-06,
#   ('/rodrigomalacarne', '/rspadim'): 6.301998923741961e-06,
#   ('/natbel4ml',): 6.816368937766524e-05,
#   ('/dengyang123',
#    '/fanhongwei',
#    '/lmqmax',
#    '/sdylovesky',
#    '/sunxinlong',
#    '/sunyao123',
#    '/yiyongjian',
#    '/yuanfirstofall',
#    '/yuankehong',
#    '/zhangshengze',
#    '/zhangxueling'): 1.0256286459806264e-06,
#   ('/wuruiaoxue',): 1.0256286459806264e-06,
#   ('/laurilistak',): 7.121731566544782e-06,
#   ('/jorgepalma',): 0.00014874708950108996,
#   ('/thuyenvn',): 2.7276979128426108e-05,
#   ('/elsazhu',): 1.0256286459806264e-06,
#   ('/andrekos', '/del=144d9653841ef5a9'): 1.0256286459806264e-06,
#   ('/zhouzhiguang',): 2.9924146693427384e-05,
#   ('/alberto2017',
#    '/mahmoudabdalah',
#    '/mavismu',
#    '/nandresparra',
#    '/yoganandb'): 1.0256286459806264e-06,
#   ('/viglia90',): 1.0256286459806264e-06,
#   ('/eige1123',
#    '/lichtenberger',
#    '/madtrini',
#    '/xxamot'): 1.0256286459806264e-06,
#   ('/icostan',): 1.910119359672011e-05,
#   ('/williamhau',): 6.503158682251495e-05,
#   ('/ahmedanis03', '/drwaleedayousef'): 6.1157060693573484e-06,
#   ('/manigandanv',): 2.4955850345144187e-05,
#   ('/twiggy',): 3.2447483391641435e-05,
#   ('/kghanareddy',): 2.6302927968148507e-05,
#   ('/goldgof',
#    '/lohall',
#    '/rahulpaul',
#    '/saeed3',
#    '/shhawkins'): 1.0256286459806264e-06,
#   ('/michalstepniewski',): 9.005102204368203e-06,
#   ('/quoctinphan',): 1.0256286459806264e-06,
#   ('/jjyang',): 1.0256286459806264e-06,
#   ('/seamri',): 1.0256286459806264e-06,
#   ('/voxelcloud',): 1.0256286459806264e-06,
#   ('/icanfly',): 1.1716471072122214e-05,
#   ('/feixyz',): 1.0256286459806264e-06,
#   ('/pandeyanil',): 5.550199233934505e-05,
#   ('/anilcem',
#    '/cberkay',
#    '/jerryqhyu',
#    '/piercingdan',
#    '/wezteoh',
#    '/xuchanbao'): 1.0256286459806264e-06,
#   ('/akh64bit',): 4.480913689843244e-05,
#   ('/hwasiti',): 1.0256286459806264e-06,
#   ('/maciek1902',): 2.032659163699984e-06,
#   ('/jorgies', '/ttuawohl', '/tturay'): 1.0256286459806264e-06,
#   ('/rrr2016',): 9.488153627055946e-05,
#   ('/zvision',): 1.0256286459806264e-06,
#   ('/raghuu045',): 1.825366513636518e-05,
#   ('/inkfly', '/pziegenhein'): 1.0256286459806264e-06,
#   ('/starethics',): 1.0256286459806264e-06,
#   ('/pengzhao99',): 1.0256286459806264e-06,
#   ('/shiny2448',): 1.0256286459806264e-06,
#   ('/lukaszn',): 4.8429372608874826e-05,
#   ('/elisayao', '/qshan2170'): 1.0256286459806264e-06,
#   ('/okazusexy',): 1.0256286459806264e-06,
#   ('/wang4959520',): 5.28040630421502e-05,
#   ('/bigheadwen001', '/cenlon', '/vikingy'): 1.0256286459806264e-06,
#   ('/simongabor',): 1.432288345881115e-05,
#   ('/bohdan',): 2.0061642139607597e-05,
#   ('/speculation',): 9.074918115694678e-05,
#   ('/qwang88',): 7.720522268916641e-05,
#   ('/derkanat',): 0.00010749478531522577,
#   ('/paragkale',): 0.00010749306076846037,
#   ('/utility',): 7.820664849954403e-05,
#   ('/kulishyurii',): 2.3636748053845818e-05,
#   ('/chechir',): 0.0001267975429138717,
#   ('/pengyan',): 6.004142240495179e-05,
#   ('/fugusuki',): 7.90496508758138e-05,
#   ('/famousboy',): 6.811111782232241e-05,
#   ('/nekrasov',): 5.346027403927631e-05,
#   ('/weimin',): 5.552867231278242e-05,
#   ('/kazanova',): 0.0001362600161006601,
#   ('/anmiko',): 8.307760452101135e-05,
#   ('/chenglongchen',): 0.00014541905597620903,
#   ('/samehif',): 8.444180848350115e-05,
#   ('/dmitriyguller',): 8.662196258699473e-05,
#   ('/zhewang',): 5.3688387077784964e-05,
#   ('/bishwarup',): 5.632766753347788e-05,
#   ('/thawatt',): 0.00015291733486190722,
#   ('/ivanliu1989',): 2.101392459052355e-05,
#   ('/danijelk',): 7.470478998377937e-05,
#   ('/johnsgr17',): 9.329167922305696e-06,
#   ('/vladteodorescu',): 8.930648031635861e-05,
#   ('/shimva',): 3.532833213248399e-05,
#   ('/raddar',): 0.0001418415119181882,
#   ('/threecourse',): 6.302134309765043e-05,
#   ('/mandelbrot',): 0.00019206036798953698,
#   ('/ouranos',): 0.0002350098581289179,
#   ('/carlosfernandez',): 1.5993199604008903e-05,
#   ('/nthanhtam',): 0.00012115819731529234,
#   ('/breakfastpirate',): 6.285626675810276e-05,
#   ('/girmak',): 0.00023740809090847653,
#   ('/chanfuku18',): 6.826831182479173e-05,
#   ('/tyi2000',): 0.00013672755844455946,
#   ('/gdanschin',): 5.058998975610574e-05,
#   ('/chabir',): 8.184585753860142e-05,
#   ('/stocks',): 0.00012327520047834204,
#   ('/wilanw',): 8.353380344979674e-05,
#   ('/trenqualye',): 0.0001066108877587359,
#   ('/davutpolat',): 7.993320182218616e-05,
#   ('/inversion',): 0.0001386136687381266,
#   ('/riblidezso',): 4.740559254042402e-05,
#   ('/kelexu',): 8.94230287615305e-05,
#   ('/ffyu1204',): 2.436297286082597e-05,
#   ('/casalicchio',): 9.957495257888242e-05,
#   ('/saintex',): 2.0168325319451063e-05,
#   ('/zfuller',): 5.485630124968457e-05,
#   ('/mt77pp',): 6.322583547498223e-05,
#   ('/deanmckee',): 7.436980447202558e-05,
#   ('/allexius',): 2.5688881162411624e-05,
#   ('/leadbest',): 0.00018935179329465616,
#   ('/paulofelipe',): 6.205093131765294e-05,
#   ('/tobiri27',): 3.745342702662822e-05,
#   ('/ivanhoe',): 0.0003122508505583313,
#   ('/ashhafez',): 5.775938623450729e-05,
#   ('/zeroblue',): 8.272686132565874e-05,
#   ('/fakeplastictrees',): 0.00010822722731162962,
#   ('/nimashahbazi',): 3.988752450431296e-05,
#   ('/jhuling',): 2.57803273190881e-05,
#   ('/snowdog',): 5.069944490466599e-05,
#   ('/jpison',): 9.458729712932781e-05,
#   ('/del=ff3f4a2063c8fa0d',): 9.329167922305696e-06,
#   ('/skylibrary',): 0.00014476910798689218,
#   ('/aldente',): 7.011255936868911e-05,
#   ('/tonyhong272',): 9.329167922305696e-06,
#   ('/xchen0012',): 2.444329301466309e-05,
#   ('/whamfish',): 5.03812781229172e-05,
#   ('/sasrdw',): 4.294214472060452e-05,
#   ('/qqgeogor',): 7.233101025464376e-05,
#   ('/jieliu',): 9.329167922305696e-06,
#   ('/ksm1978',): 5.014744293605474e-05,
#   ('/nsecord',): 0.00019780739146007308,
#   ('/santiagomota',): 0.00023077129478746265,
#   ('/newtohere',): 9.579650320681327e-05,
#   ('/del=baec042bc066df48',): 1.992972021066162e-05,
#   ('/arturabragin',): 9.650168135244731e-05,
#   ('/fohjoh',): 1.3861769923323116e-05,
#   ('/thequants',): 4.838508740366307e-05,
#   ('/michaelxiao',): 8.84946312663905e-05,
#   ('/johncandido',): 9.35031135741812e-05,
#   ('/sonador',): 9.329167922305696e-06,
#   ('/scirpus',): 0.00031116571414051064,
#   ('/tilgasergey',): 6.338242460135018e-05,
#   ('/honeye',): 9.329167922305696e-06,
#   ('/paddykb',): 9.048735874275927e-05,
#   ('/kramer',): 2.274439084375229e-05,
#   ('/assa2as',): 6.107436854628193e-05,
#   ('/jindal',): 4.567877906246631e-05,
#   ('/masandy',): 0.00011763244721492846,
#   ('/aabceh',): 5.3551554473908996e-05,
#   ('/prashanth058',): 1.3861769923323116e-05,
#   ('/cartographic',): 7.775079131637386e-05,
#   ('/nutastray',): 1.6982309995330225e-05,
#   ('/yotamsa',): 1.7973116137616426e-05,
#   ('/tinken',): 4.290035719184713e-05,
#   ('/thedarkl0rd',): 5.405629057804562e-05,
#   ('/barisumog',): 0.0002144103787385566,
#   ('/olegkulikov',): 0.00013503127793509898,
#   ('/pseudo',): 6.176036429048198e-05,
#   ('/thibmain',): 3.765263800226833e-05,
#   ('/optimism',): 7.815976137312147e-05,
#   ('/jturkewitz',): 0.0001371583725459027,
#   ('/lucenator',): 1.9687069432505562e-05,
#   ('/nianxue',): 8.150416370507196e-05,
#   ('/kanosuke',): 4.0374562531673786e-05,
#   ('/sebda1',): 8.492858261342073e-05,
#   ('/sayantan',): 0.00012200148625538287,
#   ('/sudalairajkumar',): 8.454301886416504e-05,
#   ('/sushize',): 0.00010778936855934508,
#   ('/chuan92',): 2.6313182982786757e-05,
#   ('/ccccat',): 0.00013751358638355719,
#   ('/adityashrm21',): 9.17446728784879e-05,
#   ('/dmitrylarko',): 9.873464369455547e-05,
#   ('/matlab',): 9.704306109697954e-05,
#   ('/mopkobb1',): 5.418058846703467e-05,
#   ('/qq710467272',): 9.329167922305696e-06,
#   ('/behrang',): 0.0001673937795572804,
#   ('/eransim',): 1.992972021066162e-05,
#   ('/antklen',): 0.0001540836477115751,
#   ('/allmendinger',): 0.00020256023940388678,
#   ('/kg2irq13',): 7.553001270216769e-05,
#   ('/iris2007',): 0.00017054772071925539,
#   ('/valadi',): 5.6334336700933376e-05,
#   ('/nalinpasricha',): 6.238495487086757e-05,
#   ('/jayjay75',): 0.00014606401502748786,
#   ('/lishubin',): 0.00012906622082553524,
#   ('/jonathanslomka',): 8.068380800150949e-05,
#   ('/pennacchio',): 2.445350662038544e-05,
#   ('/dmytrolystopad',): 0.00016875491909044954,
#   ('/fe2ol3t9n301be',): 5.065555134665982e-05,
#   ('/chengjiun',): 2.1118482548116808e-05,
#   ('/aurelg1106',): 5.924201159357606e-05,
#   ('/ahereza',): 1.6494973228072434e-05,
#   ('/felixds',): 7.095069436776124e-05,
#   ('/shahrdar',): 5.588750968096369e-05,
#   ('/tmwright',): 0.00015403566396753933,
#   ('/jmannix',): 1.2502641849616743e-05,
#   ('/a11rand0m',): 7.34732991611015e-05,
#   ('/jtrotman',): 0.00025632959288142925,
#   ('/vipito',): 0.0001300284994962325,
#   ('/summerpanda',): 9.329167922305696e-06,
#   ('/kushwaha',): 3.0377911858647144e-05,
#   ('/vladimirmerkulov',): 0.00011453150372112538,
#   ('/ahmetekin',): 7.560325983089455e-05,
#   ('/linchn',): 0.00015041889934674525,
#   ('/dithyrambe',): 8.486428892024131e-05,
#   ('/mrbeer',): 0.00014889286591936526,
#   ('/ahmademad',): 5.667046842097473e-05,
#   ('/timesler',): 3.6995913062607964e-05,
#   ('/akukamil',): 1.7973116137616426e-05,
#   ('/aikinogard',): 5.767030445719697e-05,
#   ('/welcomeworld',): 0.00017484216607069596,
#   ('/cckk3333',): 1.6323028428898554e-05,
#   ('/gudunku',): 6.295718230559927e-05,
#   ('/omoekan09',): 0.00010341809385466169,
#   ('/khattab34',): 0.00016608033400444488,
#   ('/yizhang4',): 4.313304527971038e-05,
#   ('/andtem2000',): 0.00011257498266356643,
#   ('/xiaoqian0917',): 9.329167922305696e-06,
#   ('/dweaii',): 1.2900879958012213e-05,
#   ('/adhirb',): 8.636330884030843e-05,
#   ('/del=f16709620a6ed7e1',): 6.728384631297066e-05,
#   ('/semwaldeepali',): 9.329167922305696e-06,
#   ('/ag3rxx',): 2.592235955368289e-05,
#   ('/jbm1966',): 0.00022793071195857342,
#   ('/skthedataguy',): 9.443463320405773e-05,
#   ('/andrekos',): 0.0002747835667532525,
#   ('/nnsmedia',): 0.00013659527527223333,
#   ('/andrejonasson',): 1.6677767565058902e-05,
#   ('/bsgdalh',): 1.6071502247113703e-05,
#   ('/neshuagrawal',): 1.460553820006703e-05,
#   ('/razgon',): 0.00012780992775531956,
#   ('/andreasmerentitis',): 1.9271830572388514e-05,
#   ('/noahxiao',): 2.4656387136481536e-05,
#   ('/makravch',): 1.992972021066162e-05,
#   ('/kperif',): 4.9033871975731356e-05,
#   ('/kalleon',): 3.900496904962959e-05,
#   ('/mathcap',): 4.2180093952448136e-05,
#   ('/sergeyivanov',): 4.561484093503732e-05,
#   ('/ferris',): 2.070334200678964e-05,
#   ('/mlandry',): 0.00015879799566949284,
#   ('/herozs',): 1.6494973228072434e-05,
#   ('/thakurrajanand',): 0.00021270882074200922,
#   ('/effywang',): 2.7340211505530096e-05,
#   ('/hongjiao',): 9.329167922305696e-06,
#   ('/luciferase',): 0.0001612848852312009,
#   ('/jamesdlawrence',): 0.000180715157118717,
#   ('/psilogram',): 0.00015574608042202777,
#   ('/yilihome',): 0.00015106187348038703,
#   ('/ghostmanandwoman',): 2.7849952223499385e-05,
#   ('/gpistre',): 9.846438197647877e-05,
#   ('/androidhk',): 0.0002402657032298015,
#   ('/albertore',): 6.726296417496843e-05,
#   ('/dllllb',): 4.465349589538166e-05,
#   ('/oivanov',): 2.4656387136481536e-05,
#   ('/justfor',): 0.00022428865416938764,
#   ('/longnguyen',): 7.887244367370121e-05,
#   ('/sterby',): 0.00022089315623087405,
#   ('/andreusancho',): 5.224840579302498e-05,
#   ('/mordoobadi',): 3.881344743459292e-05,
#   ('/tushartilwankar',): 7.311009566224962e-05,
#   ('/anttip',): 9.1689278978364e-05,
#   ('/xian9551',): 5.210030443578733e-05,
#   ('/salacika',): 1.9687069432505562e-05,
#   ('/flintaxe',): 2.491631839147742e-05,
#   ('/hingneabhishek',): 4.869696440171233e-05,
#   ('/kyazuki',): 5.1896858167829996e-05,
#   ('/tr09d0r',): 9.329167922305696e-06,
#   ('/thekvs',): 6.012924588355727e-05,
#   ('/dreeux',): 5.614372463401762e-05,
#   ('/mvansegb',): 2.4656387136481536e-05,
#   ('/zichen',): 4.210398470459009e-05,
#   ('/rengaar',): 2.7278319853414823e-05,
#   ('/milivojevic',): 0.0002869557749546226,
#   ('/kyunghk',): 5.800796799448904e-05,
#   ('/pierrenowak',): 1.6494973228072434e-05,
#   ('/mdomar',): 8.450488015686421e-05,
#   ('/etelliez',): 4.557975136443866e-05,
#   ('/reinhold',): 2.4656387136481536e-05,
#   ('/vykhand',): 0.0001876600055183415,
#   ('/del=1327ef512b2417fe',): 2.208930252457306e-05,
#   ('/rpyzurich',): 6.742486420257158e-05,
#   ('/nigelcarpenter',): 0.00024902615992583593,
#   ('/kevinwu06',): 1.9687069432505562e-05,
#   ('/mathusuthan',): 0.0002538480789970713,
#   ('/abagherp',): 9.329167922305696e-06,
#   ('/vikrant24',): 6.907816358998641e-05,
#   ('/melvindunn',): 0.00011821061192324002,
#   ('/thodime',): 0.000119138228046845,
#   ('/artimous',): 8.251059675163476e-05,
#   ('/dakindia',): 0.00014283516248495923,
#   ('/danielc777888',): 4.301998781778977e-05,
#   ('/soumendra',): 0.00022516314675894653,
#   ('/chiggypk',): 3.896791156890539e-05,
#   ('/ampaho',): 0.0001485735055282907,
#   ('/lplewa',): 0.00012928447708749263,
#   ('/tejaswagh',): 3.3869761708312083e-05,
#   ('/paolovigori',): 0.00015907003649511962,
#   ('/viktxn',): 8.586263259850887e-05,
#   ('/lnicalo',): 0.00016206297817291643,
#   ('/bonferroni27',): 0.00014784752673926017,
#   ('/bakiev',): 7.751535707990607e-05,
#   ('/titericz',): 0.00011352444215697722,
#   ('/ginoainsley',): 0.0001428960387015546,
#   ('/j55511',): 7.788607944592855e-05,
#   ('/pavel1',): 8.666220900067036e-05,
#   ('/robertkag',): 8.905414422642908e-05,
#   ('/menaka',): 4.32276179329794e-05,
#   ('/andrew31',): 3.656398276605648e-05,
#   ('/happycube',): 0.0002056370595664023,
#   ('/sergii',): 0.00010309188816652127,
#   ('/del=bf30af498c9dbd5b',): 4.310326759509255e-05,
#   ('/mattsharpe',): 4.101911418951852e-05,
#   ('/songge',): 9.329167922305696e-06,
#   ('/vinodmk',): 0.00013310363108637237,
#   ('/jianhao',): 9.329167922305696e-06,
#   ('/tszkinho',): 2.568610461573439e-05,
#   ('/dingran',): 7.07782241761869e-05,
#   ('/seiteta',): 3.546868214134138e-05,
#   ('/joswin',): 6.952098749993917e-05,
#   ('/rrgiles',): 0.00019428472005655567,
#   ('/rhinodaveb',): 9.719170176538833e-05,
#   ('/del=4295f5e274489eec',): 3.0287621720861486e-05,
#   ('/abhilashawasthi',): 0.00012995350923338564,
#   ('/odtest',): 1.992972021066162e-05,
#   ('/lantingguo',): 0.0001673099609509439,
#   ('/interesting',): 0.0002287496370853793,
#   ('/dkyang',): 3.7325242043565366e-05,
#   ('/beteemde',): 3.8000633168937035e-05,
#   ('/sionek',): 0.0002771900340338782,
#   ('/bam660',): 1.9687069432505562e-05,
#   ('/spimenov',): 0.00022445801020399165,
#   ('/sdegirmenci',): 2.1232399381525023e-05,
#   ('/utah777',): 6.64050612266919e-05,
#   ('/weberwu',): 3.0651758399383585e-05,
#   ('/klimovs',): 2.2568547195327672e-05,
#   ('/innerproduct',): 0.00013261555965219431,
#   ('/wootwoot',): 9.329167922305696e-06,
#   ('/thedoctor46',): 0.00013793305088405643,
#   ('/bernhard1',): 0.00012074233219592518,
#   ('/patstout',): 1.2819725676697856e-05,
#   ('/roshankr',): 0.00014720947059471845,
#   ('/francoisneethling',): 9.329167922305696e-06,
#   ('/piotrsoltysiak',): 9.329167922305696e-06,
#   ('/suresubs',): 0.00010975950450744333,
#   ('/shiaukuan',): 3.0195393811963252e-05,
#   ('/chistyakov',): 8.443127154349326e-05,
#   ('/howlingguineapig',): 7.422859726938381e-05,
#   ('/iridescent',): 9.329167922305696e-06,
#   ('/yihming',): 3.653062281000491e-05,
#   ('/mryusa',): 9.329167922305696e-06,
#   ('/maddarwin',): 2.776297017199043e-05,
#   ('/kmenou',): 0.00015048036117331368,
#   ('/happyphonon',): 5.59049749788441e-05,
#   ('/kaggleford',): 2.4219671433522984e-05,
#   ('/bpavlyshenko',): 9.483541925896794e-05,
#   ('/apshreyans',): 9.222636470619749e-05,
#   ('/saurabhjaju',): 5.614007278066939e-05,
#   ('/t2mretro',): 6.609819296392067e-05,
#   ('/yueben',): 9.329167922305696e-06,
#   ('/geneva',): 4.415209729205673e-05,
#   ('/georgem',): 0.0002566320861881021,
#   ('/tedferreira',): 4.3371293120920435e-05,
#   ('/vaseninamasha',): 4.9528693595201344e-05,
#   ('/sadashiv19',): 6.365428300393211e-05,
#   ('/yashrajlamsal',): 7.588848068663456e-05,
#   ('/skcary',): 4.080808705423624e-05,
#   ('/ys19931006',): 0.00012044574330904844,
#   ('/anupam1924',): 6.33193856834742e-05,
#   ('/chandlerzuo',): 2.5215116611385863e-05,
#   ('/mrthedave',): 6.888320312610603e-05,
#   ('/andrewmatte',): 6.006081199761736e-05,
#   ('/xingxu1978',): 1.7014373218072766e-05,
#   ('/infinitehorizon',): 3.3103189991104614e-05,
#   ('/frull70',): 4.561484093503732e-05,
#   ('/bobcz3',): 1.992972021066162e-05,
#   ('/thenx00',): 0.00011808297729843091,
#   ('/light94',): 4.236288828943461e-05,
#   ('/pkovacs',): 2.4656387136481536e-05,
#   ('/kaushlendrasingh',): 4.682393415802601e-05,
#   ('/santyago',): 0.0001989912605748727,
#   ('/sunjulee',): 5.27067867813904e-05,
#   ('/rajdeltarobo',): 8.830990610839721e-05,
#   ('/gingayoshizawa',): 0.00012887522941077922,
#   ('/andirey',): 8.261907522229816e-05,
#   ('/cshaley',): 3.673491704215016e-05,
#   ('/catzzz',): 3.218377723694025e-05,
#   ('/reneboy',): 0.00010242099122902169,
#   ('/korowiow',): 4.4070952828083086e-05,
#   ('/cslzhl',): 9.329167922305696e-06,
#   ('/mooniechen',): 2.4656387136481536e-05,
#   ('/qichaotang97',): 3.794076379388602e-05,
#   ('/mjstoik',): 2.1501086902106865e-05,
#   ('/dankolbman',): 4.546509719307998e-05,
#   ('/cacal39',): 7.026667292560415e-05,
#   ('/vadims',): 0.0003355962425353286,
#   ('/ngcferreira',): 9.445766239893679e-05,
#   ('/panosc',): 0.00022101565482164442,
#   ('/alextselikov',): 0.00011123866480827055,
#   ('/rykolt',): 2.4656387136481536e-05,
#   ('/robertmartin71',): 0.00023154878751294482,
#   ('/tetamhz',): 9.329167922305696e-06,
#   ('/luckymomo',): 9.329167922305696e-06,
#   ('/zzxzxzzxz',): 4.734801280315962e-05,
#   ('/del=8cfe8dec8ae8d274',): 4.272730009475695e-05,
#   ('/svpons',): 6.251365533719971e-05,
#   ('/juan001',): 3.763622136361469e-05,
#   ('/ramarsjillella',): 9.329167922305696e-06,
#   ('/evanvanness',): 9.575182183030564e-05,
#   ('/invinciblejha',): 0.0003178896258558557,
#   ('/ending',): 5.6034673585612044e-05,
#   ('/justinsu',): 9.329167922305696e-06,
#   ('/satomacoto',): 5.8091501923380845e-05,
#   ('/mikeskim',): 0.0002874549187094011,
#   ('/autostrat',): 1.8867190803019198e-05,
#   ('/wojciechmigda',): 2.4656387136481536e-05,
#   ('/pmduarte',): 9.329167922305696e-06,
#   ('/gemunu',): 1.6494973228072434e-05,
#   ('/cgratie',): 1.9687069432505562e-05,
#   ('/ceciliat',): 3.413704903203754e-05,
#   ('/santanub',): 5.165302593605251e-05,
#   ('/pritipatra',): 6.819295038946695e-05,
#   ('/ojasvi',): 3.200498677923474e-05,
#   ('/bhatth05',): 9.329167922305696e-06,
#   ('/stouzani',): 5.119587292532781e-05,
#   ('/cladier',): 2.2568547195327672e-05,
#   ('/liableminer',): 1.7265881461177386e-05,
#   ('/krishnakesavan',): 0.00022627954974571287,
#   ('/kilimnik',): 9.329167922305696e-06,
#   ('/randompulse',): 9.329167922305696e-06,
#   ('/ngaffney',): 1.6677767565058902e-05,
#   ('/gilmar2013',): 4.266743071970594e-05,
#   ('/testhaha',): 9.329167922305696e-06,
#   ('/farouktangao',): 1.9133406969209415e-05,
#   ('/vinhkhuc',): 6.14348464723975e-05,
#   ('/scsmith2',): 3.6299587454043106e-05,
#   ('/dougkoch',): 7.0089772783499e-05,
#   ('/phrendille',): 6.642791298192276e-05,
#   ('/epinephelus',): 9.908622330196959e-05,
#   ('/charlesroberson',): 9.281902473485608e-05,
#   ('/tommontroy',): 0.00014347168018674918,
#   ('/jimmyxu',): 9.329167922305696e-06,
#   ('/esperto007',): 6.275812214327818e-05,
#   ('/manels',): 0.00019513297473388311,
#   ('/cbourne',): 0.00012750825687652824,
#   ('/majhra',): 0.00013764311254523394,
#   ('/negwest1',): 5.593326135653771e-05,
#   ('/kashyapu',): 9.329167922305696e-06,
#   ('/goalminer',): 0.00012610880262554748,
#   ('/saurabhkansal',): 4.665511707921552e-05,
#   ('/lolpig',): 5.407322676387e-05,
#   ('/dlajeunesse',): 0.00012366682073929177,
#   ('/lysisza',): 5.2963440577790526e-05,
#   ('/uditsaini',): 0.00018678843959989876,
#   ('/gofordream',): 2.3843572870825642e-05,
#   ('/rohanrao',): 9.582336409000082e-05,
#   ('/brianbai',): 9.28350545267843e-05,
#   ('/johanmanders',): 4.7779166529826785e-05,
#   ('/tgalina',): 7.73154402654539e-05,
#   ('/bgeier',): 9.255662851403782e-05,
#   ('/draken',): 4.140058546837829e-05,
#   ('/yuvraj',): 9.214568853632442e-05,
#   ('/khrapal',): 2.3843572870825642e-05,
#   ('/fernandoprocy',): 0.00011814405500210289,
#   ('/mukundhingne',): 9.329167922305696e-06,
#   ('/kwartler',): 0.00014459482293537114,
#   ('/dadou46',): 3.8215135172559e-05,
#   ('/deidei',): 1.2900879958012213e-05,
#   ('/neuro17',): 2.4656387136481536e-05,
#   ('/kbartol',): 7.73945398138319e-05,
#   ('/achursov',): 0.00012833707545178652,
#   ('/lucienderubempre',): 6.656770318566157e-05,
#   ('/jeongyoonlee',): 0.00017281606969778312,
#   ('/anthonyp',): 0.0001428073397877559,
#   ('/alexsmith21',): 6.908020299538062e-05,
#   ('/del=981949bcab6a4072',): 4.5941403493117654e-05,
#   ('/m4ch1n3',): 4.5880310388470366e-05,
#   ('/alexlzzz',): 0.0001056419338920032,
#   ('/mconway',): 0.00012822223788497183,
#   ('/juvleo',): 1.6677767565058902e-05,
#   ('/xingwei',): 9.329167922305696e-06,
#   ('/anilkumar469',): 0.00010815780037394818,
#   ('/anjanaagrawal',): 0.00017415631797417487,
#   ('/indradenbakker',): 4.4864185986441176e-05,
#   ('/rybick',): 1.5088328874055708e-05,
#   ('/johnxllis',): 3.917079208500148e-05,
#   ('/dominique',): 0.00033551839824727975,
#   ('/fcastanedo',): 9.186756387780204e-05,
#   ('/mingshan',): 9.329167922305696e-06,
#   ('/shenwenlong',): 0.0001529711609854283,
#   ('/armaseg',): 9.329167922305696e-06,
#   ('/gracegimon',): 9.329167922305696e-06,
#   ('/ctrabuco',): 1.6224181637674732e-05,
#   ('/sdrapak',): 2.814694489087369e-05,
#   ('/nilotpal',): 0.00022475907759861942,
#   ('/bosukh',): 3.292840289268761e-05,
#   ('/codebender',): 0.00010500604381259283,
#   ('/sergiorivera',): 9.329167922305696e-06,
#   ('/domashnev',): 9.329167922305696e-06,
#   ('/michaelpawlus',): 0.00024529808263861917,
#   ('/usixuz',): 0.00011777165228162741,
#   ('/srikiyer',): 0.0001298297394307636,
#   ('/mattvonrohr',): 0.00012986710249296603,
#   ('/njuysen',): 9.329167922305696e-06,
#   ('/janekk',): 5.594423885777319e-05,
#   ('/apsgiles',): 3.3088283949972854e-05,
#   ('/benjamwhite',): 3.763622136361469e-05,
#   ('/jiaqianqian',): 9.329167922305696e-06,
#   ('/xiaolaoshu',): 9.329167922305696e-06,
#   ('/zaxcie',): 7.498903630222723e-05,
#   ('/fernandoconstantino',): 1.6439725127038177e-05,
#   ('/instigator',): 4.889760005117904e-05,
#   ('/ghellstern',): 4.921127076305871e-05,
#   ...},
#  {6004: 0.0012723980783607572,
#   4699: 0.011573794651276554,
#   4571: 0.0011583045029503471,
#   4657: 0.009116695502534114,
#   4494: 0.00024558133591741707,
#   4504: 0.004412214864533907,
#   4704: 0.00562316009665903,
#   4521: 0.0019171411263437274,
#   4594: 0.013151078037968125,
#   4523: 0.00040852322290967747,
#   4487: 0.009846311425617982,
#   4493: 0.0018234715141035992,
#   4488: 0.004292599537269145,
#   4481: 0.005551727566730147,
#   4467: 0.00649673603085469,
#   4471: 0.009534289519373122,
#   4453: 0.0022990118447356414,
#   4438: 0.0028669759497259276,
#   4104: 0.002438462691845867,
#   4407: 0.0059544033661037025,
#   4366: 0.005825065678136989,
#   4280: 0.010723708958124235,
#   4272: 0.0075628441853814515,
#   4066: 0.0011074095205712577,
#   3978: 0.0033890963788204866,
#   4031: 0.00433039677323884,
#   4120: 0.004431077026271758,
#   3973: 0.001848032651472748,
#   3984: 0.0020743502287146826,
#   3887: 0.003937021594183141,
#   3951: 0.0025103981487232065,
#   3929: 0.0009854681098238414,
#   3897: 0.002260241222642836,
#   3778: 0.0002556525815058795,
#   3788: 0.003609193966909826,
#   3706: 0.000399867846968872,
#   3867: 0.0008026795744626206,
#   3757: 0.00025156136488525555,
#   3670: 0.0008244892185703068,
#   3532: 0.00039849954475248414,
#   3618: 0.00014578977736189015,
#   3599: 0.0011229020991856465,
#   3504: 0.0008498729630474576,
#   3526: 0.0013943636755325663,
#   2969: 0.0005369349691265795,
#   3403: 0.00025543366775128873,
#   3525: 3.624527861477377e-05,
#   3338: 0.002385679653780948,
#   3445: 0.00048672782123164546,
#   3446: 0.00038954310608142723,
#   3493: 0.0003257412567288506,
#   3316: 0.0008970427132657176,
#   3469: 0.0003529108007788367,
#   3353: 0.0003876070505130292,
#   2496: 0.0010616586351648977,
#   3342: 0.0006324711037582855,
#   3288: 0.00032070538319400605,
# ...
#   ('/fohjoh',): 6.946427866142164e-06,
#   ('/thequants',): 2.4246796859607946e-05,
#   ('/michaelxiao',): 4.434654275976938e-05,
#   ('/johncandido',): 4.685639981736239e-05,
#   ('/sonador',): 4.675044556496572e-06,
#   ('/scirpus',): 0.0001559317604915811,
#   ('/tilgasergey',): 3.176228165004628e-05,
#   ('/honeye',): 4.675044556496572e-06,
#   ('/paddykb',): 4.5345140900440045e-05,
#   ('/kramer',): 1.1397698218080423e-05,
#   ('/assa2as',): 3.0605665648983405e-05,
#   ('/jindal',): 2.289060816373373e-05,
#   ('/masandy',): 5.8948122340042216e-05,
#   ('/aabceh',): 2.6835823443242222e-05,
#   ('/prashanth058',): 6.946427866142164e-06,
#   ('/cartographic',): 3.896257594811567e-05,
#   ('/nutastray',): 8.510196896605899e-06,
#   ('/yotamsa',): 9.006710937388071e-06,
#   ('/tinken',): 2.1498281843755677e-05,
#   ('/thedarkl0rd',): 2.7088757444919434e-05,
#   ('/barisumog',): 0.0001074456031151674,
#   ('/olegkulikov',): 6.766704663467538e-05,
#   ('/pseudo',): 3.094943271303246e-05,
#   ('/thibmain',): 1.8868538094314745e-05,
#   ('/optimism',): 3.9167519545890596e-05,
#   ('/jturkewitz',): 6.87329790057596e-05,
#   ('/lucenator',): 9.865609403786034e-06,
#   ('/nianxue',): 4.08434707183872e-05,
#   ('/kanosuke',): 2.023255239444508e-05,
#   ('/sebda1',): 4.2559519899721226e-05,
#   ('/sayantan',): 6.113754076988663e-05,
#   ('/sudalairajkumar',): 4.2366305700523666e-05,
#   ('/sushize',): 5.40155461795235e-05,
#   ('/chuan92',): 1.3186095897510585e-05,
#   ('/ccccat',): 6.891098421836973e-05,
#   ('/adityashrm21',): 4.597520776753474e-05,
#   ('/dmitrylarko',): 4.947803087933833e-05,
#   ('/matlab',): 4.863034284558049e-05,
#   ('/mopkobb1',): 2.715104576198683e-05,
#   ('/qq710467272',): 4.675044556496572e-06,
#   ('/behrang',): 8.388458482297093e-05,
#   ('/eransim',): 9.987206871972035e-06,
#   ('/antklen',): 7.721459453547188e-05,
#   ('/allmendinger',): 0.00010150724614083683,
#   ('/kg2irq13',): 3.7849696529812285e-05,
#   ('/iris2007',): 8.54650918501676e-05,
#   ('/valadi',): 2.82303348303933e-05,
#   ('/nalinpasricha',): 3.126242834344977e-05,
#   ('/jayjay75',): 7.319578595179111e-05,
#   ('/lishubin',): 6.46778295901921e-05,
#   ('/jonathanslomka',): 4.043237301924718e-05,
#   ('/pennacchio',): 1.2254172501225084e-05,
#   ('/dmytrolystopad',): 8.45666808062353e-05,
#   ('/fe2ol3t9n301be',): 2.5384574653569687e-05,
#   ('/chengjiun',): 1.0582920974308358e-05,
#   ('/aurelg1106',): 2.968743259025945e-05,
#   ('/ahereza',): 8.265982072747954e-06,
#   ('/felixds',): 3.5554902671498765e-05,
#   ('/shahrdar',): 2.8006420302880715e-05,
#   ('/tmwright',): 7.719054886034363e-05,
#   ('/jmannix',): 6.265339868214189e-06,
#   ('/a11rand0m',): 3.681903361016721e-05,
#   ('/jtrotman',): 0.0001284522132988077,
#   ('/vipito',): 6.516004790744276e-05,
#   ('/summerpanda',): 4.675044556496572e-06,
#   ('/kushwaha',): 1.5223018028454555e-05,
#   ('/vladimirmerkulov',): 5.7394173571707334e-05,
#   ('/ahmetekin',): 3.788640222465594e-05,
#   ('/linchn',): 7.537811114995492e-05,
#   ('/dithyrambe',): 4.2527300962000596e-05,
#   ('/mrbeer',): 7.461338332694421e-05,
#   ('/ahmademad',): 2.8398777587797284e-05,
#   ('/timesler',): 1.853943925293158e-05,
#   ('/akukamil',): 9.006710937388071e-06,
#   ('/aikinogard',): 2.889981670039233e-05,
#   ('/welcomeworld',): 8.761712979483532e-05,
#   ('/cckk3333',): 8.179816875164422e-06,
#   ('/gudunku',): 3.1549183687169905e-05,
#   ('/omoekan09',): 5.182500741173848e-05,
#   ('/khattab34',): 8.322638930796085e-05,
#   ('/yizhang4',): 2.1614886795863342e-05,
#   ('/andtem2000',): 5.641371923831294e-05,
#   ('/xiaoqian0917',): 4.675044556496572e-06,
#   ('/dweaii',): 6.464905458237613e-06,
#   ('/adhirb',): 4.327849174074022e-05,
#   ('/del=f16709620a6ed7e1',): 3.371736708625346e-05,
#   ('/semwaldeepali',): 4.675044556496572e-06,
#   ('/ag3rxx',): 1.2990245961102547e-05,
#   ('/jbm1966',): 0.00011422092978327475,
#   ('/skthedataguy',): 4.732320412507978e-05,
#   ('/andrekos',): 0.00013769989227841088,
#   ('/nnsmedia',): 6.845079897990387e-05,
#   ('/andrejonasson',): 8.357584204601739e-06,
#   ('/bsgdalh',): 8.053771753367827e-06,
#   ('/neshuagrawal',): 7.319145975862813e-06,
#   ('/razgon',): 6.404827440051637e-05,
#   ('/andreasmerentitis',): 9.65752437532462e-06,
#   ('/noahxiao',): 1.2355840244845686e-05,
#   ('/makravch',): 9.987206871972035e-06,
#   ('/kperif',): 2.457191661390682e-05,
#   ('/kalleon',): 1.954621995769433e-05,
#   ('/mathcap',): 2.113734260838653e-05,
#   ('/sergeyivanov',): 2.2858567407610613e-05,
#   ('/ferris',): 1.0374885215470381e-05,
#   ('/mlandry',): 7.957705461145242e-05,
#   ('/herozs',): 8.265982072747954e-06,
#   ('/thakurrajanand',): 0.0001065929161954283,
#   ('/effywang',): 1.370076174389536e-05,
#   ('/hongjiao',): 4.675044556496572e-06,
#   ('/luciferase',): 8.08232878883907e-05,
#   ('/jamesdlawrence',): 9.05602105781446e-05,
#   ('/psilogram',): 7.804767494089811e-05,
#   ('/yilihome',): 7.570031916926003e-05,
#   ('/ghostmanandwoman',): 1.3956203664064661e-05,
#   ('/gpistre',): 4.9342596981737044e-05,
#   ('/androidhk',): 0.00012040225637939574,
#   ('/albertore',): 3.370690260223296e-05,
#   ('/dllllb',): 2.2376816952275066e-05,
#   ('/oivanov',): 1.2355840244845686e-05,
#   ('/justfor',): 0.00011239581712759655,
#   ('/longnguyen',): 3.9524659811268044e-05,
#   ('/sterby',): 0.0001106942608593583,
#   ('/andreusancho',): 2.618278791020888e-05,
#   ('/mordoobadi',): 1.9450244401135782e-05,
#   ('/tushartilwankar',): 3.6637024608959464e-05,
#   ('/anttip',): 4.594744870486153e-05,
#   ('/xian9551',): 2.6108571168677802e-05,
#   ('/salacika',): 9.865609403786034e-06,
#   ('/flintaxe',): 1.2486097327590234e-05,
#   ('/hingneabhishek',): 2.440308505956656e-05,
#   ('/kyazuki',): 2.600661991479404e-05,
#   ('/tr09d0r',): 4.675044556496572e-06,
#   ('/thekvs',): 3.0132044571967162e-05,
#   ('/dreeux',): 2.8134815067923618e-05,
#   ('/mvansegb',): 1.2355840244845686e-05,
#   ('/zichen',): 2.1099202644803707e-05,
#   ('/rengaar',): 1.3669746520077203e-05,
#   ('/milivojevic',): 0.00014379964481460688,
#   ('/kyunghk',): 2.9069027083966697e-05,
#   ('/pierrenowak',): 8.265982072747954e-06,
#   ('/mdomar',): 4.2347193583079796e-05,
#   ('/etelliez',): 2.284098327705175e-05,
#   ('/reinhold',): 1.2355840244845686e-05,
#   ('/vykhand',): 9.404042188621044e-05,
#   ('/del=1327ef512b2417fe',): 1.1069419522130013e-05,
#   ('/rpyzurich',): 3.3788034150697836e-05,
#   ('/nigelcarpenter',): 0.00012479230763917505,
#   ('/kevinwu06',): 9.865609403786034e-06,
#   ('/mathusuthan',): 0.0001272086738890632,
#   ('/abagherp',): 4.675044556496572e-06,
#   ('/vikrant24',): 3.461653765412774e-05,
#   ('/melvindunn',): 5.923785297809983e-05,
#   ('/thodime',): 5.9702701155993195e-05,
#   ('/artimous',): 4.134781573302762e-05,
#   ('/dakindia',): 7.157773923801803e-05,
#   ('/danielc777888',): 2.1558231295987774e-05,
#   ('/soumendra',): 0.00011283404397218522,
#   ('/chiggypk',): 1.9527649665581637e-05,
#   ('/ampaho',): 7.445334504021545e-05,
#   ('/lplewa',): 6.478720244699991e-05,
#   ('/tejaswagh',): 1.6972858289496014e-05,
#   ('/paolovigori',): 7.971338005821228e-05,
#   ('/viktxn',): 4.302759222241171e-05,
#   ('/lnicalo',): 8.12132068182026e-05,
#   ('/bonferroni27',): 7.408954162149921e-05,
#   ('/bakiev',): 3.884459484265443e-05,
#   ('/titericz',): 5.688951359339359e-05,
#   ('/ginoainsley',): 7.16082456056273e-05,
#   ('/j55511',): 3.9030371708719906e-05,
#   ('/pavel1',): 4.3428276970866135e-05,
#   ('/robertkag',): 4.462692660944623e-05,
#   ('/menaka',): 2.16622791647436e-05,
#   ('/andrew31',): 1.8322989790431523e-05,
#   ('/happycube',): 0.00010304910619453828,
#   ('/sergii',): 5.166153879984858e-05,
#   ('/del=bf30af498c9dbd5b',): 2.1599964564450787e-05,
#   ('/mattsharpe',): 2.0555550945298483e-05,
#   ('/songge',): 4.675044556496572e-06,
#   ('/vinodmk',): 6.670106178158596e-05,
#   ('/jianhao',): 4.675044556496572e-06,
#   ('/tszkinho',): 1.2871853584491547e-05,
#   ('/dingran',): 3.546847418855438e-05,
#   ('/seiteta',): 1.777411134111859e-05,
#   ('/joswin',): 3.483844613762566e-05,
#   ('/rrgiles',): 9.736020730555883e-05,
#   ('/rhinodaveb',): 4.870482984736241e-05,
#   ('/del=4295f5e274489eec',): 1.51777717192615e-05,
#   ('/abhilashawasthi',): 6.512246869064327e-05,
#   ('/odtest',): 9.987206871972035e-06,
#   ('/lantingguo',): 8.384258153595101e-05,
#   ('/interesting',): 0.00011463131058992514,
#   ('/dkyang',): 1.8704473012918716e-05,
#   ('/beteemde',): 1.9042925877143215e-05,
#   ('/sionek',): 0.0001389058242388751,
#   ('/bam660',): 9.865609403786034e-06,
#   ('/spimenov',): 0.00011248068504083846,
#   ('/sdegirmenci',): 1.0640007123530901e-05,
#   ('/utah777',): 3.327698917993377e-05,
#   ('/weberwu',): 1.5360248357145984e-05,
#   ('/klimovs',): 1.1309579224098738e-05,
#   ('/innerproduct',): 6.645647880066665e-05,
#   ('/wootwoot',): 4.675044556496572e-06,
#   ('/thedoctor46',): 6.912118680509076e-05,
#   ('/bernhard1',): 6.0506551877639826e-05,
#   ('/patstout',): 6.424237321030684e-06,
#   ('/roshankr',): 7.376979811043418e-05,
#   ('/francoisneethling',): 4.675044556496572e-06,
#   ('/piotrsoltysiak',): 4.675044556496572e-06,
#   ('/suresubs',): 5.5002823225386656e-05,
#   ('/shiaukuan',): 1.5131554351603746e-05,
#   ('/chistyakov',): 4.231030674022918e-05,
#   ('/howlingguineapig',): 3.719752956426713e-05,
#   ('/iridescent',): 4.675044556496572e-06,
#   ('/yihming',): 1.8306272406679703e-05,
#   ('/mryusa',): 4.675044556496572e-06,
#   ('/maddarwin',): 1.3912615107352446e-05,
#   ('/kmenou',): 7.540891097859209e-05,
#   ('/happyphonon',): 2.8015172534892442e-05,
#   ('/kaggleford',): 1.2136992713431625e-05,
#   ('/bpavlyshenko',): 4.752404654505966e-05,
#   ('/apshreyans',): 4.621659379219672e-05,
#   ('/saurabhjaju',): 2.8132985046384184e-05,
#   ('/t2mretro',): 3.312321096381585e-05,
#   ('/yueben',): 4.675044556496572e-06,
#   ('/geneva',): 2.2125555443121594e-05,
#   ('/georgem',): 0.00012860379913140897,
#   ('/tedferreira',): 2.1734277858596248e-05,
#   ('/vaseninamasha',): 2.4819882256491697e-05,
#   ('/sadashiv19',): 3.1898515680384305e-05,
#   ('/yashrajlamsal',): 3.8029332464571543e-05,
#   ('/skcary',): 2.0449800757255124e-05,
#   ('/ys19931006',): 6.0357924875671625e-05,
#   ('/anupam1924',): 3.173069150703994e-05,
#   ('/chandlerzuo',): 1.2635831473603055e-05,
#   ('/mrthedave',): 3.45188388167277e-05,
#   ('/andrewmatte',): 3.0097750895283168e-05,
#   ('/xingxu1978',): 8.526264459793467e-06,
#   ('/infinitehorizon',): 1.6588712890535925e-05,
#   ('/frull70',): 2.2858567407610613e-05,
#   ('/bobcz3',): 9.987206871972035e-06,
#   ('/thenx00',): 5.9173892551875966e-05,
#   ('/light94',): 2.1228944740240317e-05,
#   ('/pkovacs',): 1.2355840244845686e-05,
#   ('/kaushlendrasingh',): 2.3464469749311563e-05,
#   ('/santyago',): 9.971875490700538e-05,
#   ('/sunjulee',): 2.6412492377091475e-05,
#   ('/rajdeltarobo',): 4.4253973052567115e-05,
#   ('/gingayoshizawa',): 6.458211972831439e-05,
#   ('/andirey',): 4.14021766031598e-05,
#   ('/cshaley',): 1.840864859346059e-05,
#   ('/catzzz',): 1.6127975595614545e-05,
#   ('/reneboy',): 5.132533806908797e-05,
#   ('/korowiow',): 2.2084892225511972e-05,
#   ('/cslzhl',): 4.675044556496572e-06,
#   ('/mooniechen',): 1.2355840244845686e-05,
#   ('/qichaotang97',): 1.9012924059370827e-05,
#   ('/mjstoik',): 1.077465215727287e-05,
#   ('/dankolbman',): 2.2783527632092835e-05,
#   ('/cacal39',): 3.5212124971889493e-05,
#   ('/vadims',): 0.00016817441811502586,
#   ('/ngcferreira',): 4.733474454421202e-05,
#   ('/panosc',): 0.00011075564751001302,
#   ('/alextselikov',): 5.574406192585314e-05,
#   ('/rykolt',): 1.2355840244845686e-05,
#   ('/robertmartin71',): 0.00011603402443070196,
#   ('/tetamhz',): 4.675044556496572e-06,
#   ('/luckymomo',): 4.675044556496572e-06,
#   ('/zzxzxzzxz',): 2.372709670983513e-05,
#   ('/del=8cfe8dec8ae8d274',): 2.1411559250016863e-05,
#   ('/svpons',): 3.1326922885790586e-05,
#   ('/juan001',): 1.8860311367366666e-05,
#   ('/ramarsjillella',): 4.675044556496572e-06,
#   ('/evanvanness',): 4.798327537357385e-05,
#   ('/invinciblejha',): 0.00015930125572727056,
#   ('/ending',): 2.808016726710151e-05,
#   ('/justinsu',): 4.675044556496572e-06,
#   ('/satomacoto',): 2.911088771341639e-05,
#   ('/mikeskim',): 0.00014404977637080257,
#   ('/autostrat',): 9.454750776767681e-06,
#   ('/wojciechmigda',): 1.2355840244845686e-05,
#   ('/pmduarte',): 4.675044556496572e-06,
#   ('/gemunu',): 8.265982072747954e-06,
#   ('/cgratie',): 9.865609403786034e-06,
#   ('/ceciliat',): 1.7106801654762092e-05,
#   ('/santanub',): 2.588443039499171e-05,
#   ('/pritipatra',): 3.417293848336551e-05,
#   ('/ojasvi',): 1.6038379892950852e-05,
#   ('/bhatth05',): 4.675044556496572e-06,
#   ('/stouzani',): 2.5655341293890868e-05,
#   ('/cladier',): 1.1309579224098738e-05,
#   ('/liableminer',): 8.652300592128179e-06,
#   ('/krishnakesavan',): 0.00011339349726398692,
#   ('/kilimnik',): 4.675044556496572e-06,
#   ('/randompulse',): 4.675044556496572e-06,
#   ('/ngaffney',): 8.357584204601739e-06,
#   ('/gilmar2013',): 2.138155743224447e-05,
#   ('/testhaha',): 4.675044556496572e-06,
#   ('/farouktangao',): 9.58815736231264e-06,
#   ('/vinhkhuc',): 3.078630880821861e-05,
#   ('/scsmith2',): 1.8190495673733768e-05,
#   ('/dougkoch',): 3.512347654651138e-05,
#   ('/phrendille',): 3.328844068111745e-05,
#   ('/epinephelus',): 4.9654214901621464e-05,
#   ('/charlesroberson',): 4.651358834352483e-05,
#   ('/tommontroy',): 7.189671180223353e-05,
#   ('/jimmyxu',): 4.675044556496572e-06,
#   ('/esperto007',): 3.14494304039995e-05,
#   ('/manels',): 9.778528577333761e-05,
#   ('/cbourne',): 6.389710070419299e-05,
#   ('/majhra',): 6.897589253366205e-05,
#   ('/negwest1',): 2.8029347441254812e-05,
#   ('/kashyapu',): 4.675044556496572e-06,
#   ('/goalminer',): 6.319580440066021e-05,
#   ('/saurabhkansal',): 2.33798719189565e-05,
#   ('/lolpig',): 2.7097244528134264e-05,
#   ('/dlajeunesse',): 6.197207531550073e-05,
#   ('/lysisza',): 2.6541107055715782e-05,
#   ('/uditsaini',): 9.360366165924046e-05,
#   ('/gofordream',): 1.1948521720853122e-05,
#   ('/rohanrao',): 4.8019126722178766e-05,
#   ('/brianbai',): 4.652162121341622e-05,
#   ('/johanmanders',): 2.3943157016739005e-05,
#   ('/tgalina',): 3.874441227292836e-05,
#   ('/bgeier',): 4.638209601382224e-05,
#   ('/draken',): 2.074671432013988e-05,
#   ('/yuvraj',): 4.6176165246783535e-05,
#   ('/khrapal',): 1.1948521720853122e-05,
#   ('/fernandoprocy',): 5.920449988886426e-05,
#   ('/mukundhingne',): 4.675044556496572e-06,
#   ('/kwartler',): 7.245954253262748e-05,
#   ('/dadou46',): 1.9150417395432668e-05,
#   ('/deidei',): 6.464905458237613e-06,
#   ('/neuro17',): 1.2355840244845686e-05,
#   ('/kbartol',): 3.878405073978445e-05,
#   ('/achursov',): 6.431243932812204e-05,
#   ('/lucienderubempre',): 3.335849252651582e-05,
#   ('/jeongyoonlee',): 8.660180979024107e-05,
#   ('/anthonyp',): 7.156379669248296e-05,
#   ('/alexsmith21',): 3.4617559643553346e-05,
#   ('/del=981949bcab6a4072',): 2.302221485418851e-05,
#   ('/m4ch1n3',): 2.2991599799479605e-05,
#   ('/alexlzzz',): 5.2939420974216996e-05,
#   ('/mconway',): 6.425489177977971e-05,
#   ('/juvleo',): 8.357584204601739e-06,
#   ('/xingwei',): 4.675044556496572e-06,
#   ('/anilkumar469',): 5.42001752016142e-05,
#   ('/anjanaagrawal',): 8.727343672050956e-05,
#   ('/indradenbakker',): 2.24823982399587e-05,
#   ('/rybick',): 7.561082655660218e-06,
#   ('/johnxllis',): 1.9629317409202235e-05,
#   ('/dominique',): 0.00016813540868583575,
#   ('/fcastanedo',): 4.6036791061959364e-05,
#   ('/mingshan',): 4.675044556496572e-06,
#   ('/shenwenlong',): 7.66571037652424e-05,
#   ('/armaseg',): 4.675044556496572e-06,
#   ('/gracegimon',): 4.675044556496572e-06,
#   ('/ctrabuco',): 8.130282644751627e-06,
#   ('/sdrapak',): 1.41050330093798e-05,
#   ('/nilotpal',): 0.00011263155631859839,
#   ('/bosukh',): 1.6501123356241878e-05,
#   ('/codebender',): 5.2620762924692796e-05,
#   ('/sergiorivera',): 4.675044556496572e-06,
#   ('/domashnev',): 4.675044556496572e-06,
#   ('/michaelpawlus',): 0.00012292408878243453,
#   ('/usixuz',): 5.901788096142525e-05,
#   ('/srikiyer',): 6.506044500946343e-05,
#   ('/mattvonrohr',): 6.507916843531416e-05,
#   ('/njuysen',): 4.675044556496572e-06,
#   ('/janekk',): 2.8034848500399878e-05,
#   ('/apsgiles',): 1.6581243156108258e-05,
#   ('/benjamwhite',): 1.8860311367366666e-05,
#   ('/jiaqianqian',): 4.675044556496572e-06,
#   ('/xiaolaoshu',): 4.675044556496572e-06,
#   ('/zaxcie',): 3.757860174444156e-05,
#   ('/fernandoconstantino',): 8.238296073729591e-06,
#   ('/instigator',): 2.4503627852697583e-05,
#   ('/ghellstern',): 2.4660814920927174e-05,
#   ...})
